# %%
# Заполните пропуски в столбцах Engine и Power средними значениями для данных моделей. - датасет из нашего урока

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
data = pd.read_csv(list(files.upload().keys())[0])

# %%
# Проверьте, остались ли еще в датасете пропущенные значения. Почему? Что с ними можно сделать?

# %% [markdown]
# задания ниже связаны

# %%
# Скачайте файл. Изучите датасет.
# https://drive.google.com/file/d/1aENPbicbfLDsRw3maE0JJDneRGO1_UYW/view

# %%
# Выполните первичный анализ датасета
# (количество строк и столбцов, значения и типы данных, наличие отсутствующих значений,
# наличие категориальных столбцов, наличие дубликатов строк).
# Исправьте выявленные ошибки заполнения датасета. При необходимости выполните другие преобразования.

# %%
# Добавьте столбец Sum с суммой всех баллов

# %%
# Выполните одномерный анализ всех столбцов, включая добавленный

# %%
# Выполните двумерный анализ влияния каждого фактора на столбец Sum

# %%
# Выполните многомерный анализ с помощью цветовой карты корреляционной матрицы.

# %%
# Заполните пропущенные значения наиболее подходящим способом.

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# Sample Eda Data - dataSet

# %%
# 🧹 Очистка данных: Найдите и заполните пропущенные значения в столбце Age медианой по полу (Gender).

# %%
# 📊 Анализ распределения: Постройте гистограмму распределения зарплат (Salary) и определите, есть ли выбросы.

# %%
# 📈 Сравнительный анализ: Вычислите среднюю зарплату в каждом департаменте (Department) и постройте bar chart.

# %%
# 🧑‍🤝‍🧑 Гендерный разрез: Определите, в каком департаменте наибольшее количество женщин.

# %%
# 📆 Анализ по стажу: Добавьте новый столбец YearsAtCompany, вычислив количество лет с момента StartDate.

# %%
# 🔍 Фильтрация: Найдите всех сотрудников моложе 30 лет с зарплатой выше медианной по всем.

# %%
# 📅 Группировка: Группируйте сотрудников по годам начала работы (StartDate) и посчитайте количество сотрудников, пришедших в каждый год.

# %%
# 📌 Корреляция: Исследуйте взаимосвязь между возрастом (Age) и зарплатой (Salary) при помощи scatter plot.

# %%
# 🧠 Предсказание: Постройте простую регрессионную модель, предсказывающую Salary по Age.

# %%
# 📎 Визуализация: Постройте boxplot зарплат по департаментам, разбитый по полу (Gender)
