# %% [markdown]
# # <b><font color='rebeccapurple'>Practicum 14</font></b>

# %% [markdown]
# ### <font color='rebeccapurple'>1. Описание датасета</font>

# %% [markdown]
# Набор данных spotify_songs содержит информацию о почти 30 000 песен из API Spotify. Описание данных в файле readme.md

# %%
pip install pygwalker
# Out:
# ...
#    ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#    -------- ------------------------------- 1.0/4.8 MB 11.2 MB/s eta 0:00:01
#    ------------------------- -------------- 3.1/4.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.8/4.8 MB 8.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/956.2 kB ? eta -:--:--
#    ---------------------------------------- 956.2/956.2 kB 21.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    --------------------------- ------------ 8.9/13.1 MB 43.9 MB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 44.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/687.8 kB ? eta -:--:--
#    ---------------------------------------- 687.8/687.8 kB 18.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.4 MB 14.6 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import pygwalker as pyg

df = pd.read_csv("spotify_songs.csv")
pyg.walk(df)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000651cc2bffb381TDAK9WChXGwO71rE" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000651cc2bffb381TDAK9WChXGwO71rE") {
#             var iframe = document.getElementById("gwalker-000651cc2bffb381TDAK9WChXGwO71rE");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
