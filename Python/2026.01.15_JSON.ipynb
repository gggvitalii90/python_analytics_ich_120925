# %%
import json
data = {'name': 'Alice', 'age': 25, 'is_student': False}
print(type(data))
json_string = json.dumps(data) # Преобразование в JSON-строку
print(type(json_string))
print(json_string)
# Out:
# <class 'dict'>
# <class 'str'>
# {"name": "Alice", "age": 25, "is_student": false}

# %%
data = {"name": "Alice", "age": 25, "is_student": False}
with open("data.json", "w") as file:
 json.dump(data, file) # Запись JSON в файл

# %%
with open("data.json", "r") as file:
    x = file.read()
    print(x)
# Out:
# {"name": "Alice", "age": 25, "is_student": false}

# %%
json_object = '{"name": "Alice", "age": 25, "is_student": false}'
json_objects = '[{"name": "Alice", "age": 25, "is_student": false},{"name": "Bob", "age": 20, "is_student": true}]'
data_dict = json.loads(json_object) # Преобразование JSON-строки в Python-объект
print(type(data_dict))
print(data_dict)
data_list = json.loads(json_objects) # Преобразование JSON-строки в Python-объект
print(type(data_list))
print(data_list)
# Out:
# <class 'dict'>
# {'name': 'Alice', 'age': 25, 'is_student': False}
# <class 'list'>
# [{'name': 'Alice', 'age': 25, 'is_student': False}, {'name': 'Bob', 'age': 20, 'is_student': True}]

# %%
with open("data.json", "r") as file:
 data = json.load(file) # Загрузка JSON из файла
print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'name': 'Alice', 'age': 25, 'is_student': False}

# %%
a = {
 "dict_example": {"key": "value"},
 "list_example": ["apple", "banana"],
 "tuple_example": ("apple", "banana"),
 "string_example": "Hello",
 "int_example": 42,
 "float_example": 3.14,
 "bool_example_true": True,
 "bool_example_false": False,
 "none_example": None
}
# Запись в файл data.json
with open("data2.json", "w", encoding="utf-8") as file:
 json.dump(a, file)

# %%
with open("data2.json", "r") as file:
    y = file.read()
    print(y)
    print(type(y))
# Out:
# {"dict_example": {"key": "value"}, "list_example": ["apple", "banana"], "tuple_example": ["apple", "banana"], "string_example": "Hello", "int_example": 42, "float_example": 3.14, "bool_example_true": true, "bool_example_false": false, "none_example": null}
# <class 'str'>

# %%
# Чтение данных обратно в Python
with open("data.json", "r", encoding="utf-8") as file:
 loaded_data = json.load(file)
# Вывод загруженных данных
print(type(loaded_data))
print(loaded_data)
# Out:
# <class 'dict'>
# {'name': 'Alice', 'age': 25, 'is_student': False}

# %%
data = {"name": "Alice", "age": 25, "is_student": False, "courses": {"math": "A", "physics": "B" }}
json_string = json.dumps(data) # Без отступа
print(json_string)
json_string = json.dumps(data, indent=4) # С отступом
print(json_string)
# Out:
# {"name": "Alice", "age": 25, "is_student": false, "courses": {"math": "A", "physics": "B"}}
# {
#     "name": "Alice",
#     "age": 25,
#     "is_student": false,
#     "courses": {
#         "math": "A",
#         "physics": "B"
#     }
# }

# %%
data = {"город": "Берлин", "страна": "Германия"}
json_string = json.dumps(data) # По умолчанию (ensure_ascii=True)
print(json_string)
json_string = json.dumps(data, ensure_ascii=False) # Отключаем ASCIIкодировку
print(json_string)
# Out:
# {"\u0433\u043e\u0440\u043e\u0434": "\u0411\u0435\u0440\u043b\u0438\u043d", "\u0441\u0442\u0440\u0430\u043d\u0430": "\u0413\u0435\u0440\u043c\u0430\u043d\u0438\u044f"}
# {"город": "Берлин", "страна": "Германия"}

# %%
data = {"name": "Alice", "age": 25, "is_student": False, "city":
"London"}
json_string = json.dumps(data, indent=4) # Без сортировки ключей
print(json_string)
json_string = json.dumps(data, indent=4, sort_keys=True) # Сортировка ключей
print(json_string)
# Out:
# {
#     "name": "Alice",
#     "age": 25,
#     "is_student": false,
#     "city": "London"
# }
# {
#     "age": 25,
#     "city": "London",
#     "is_student": false,
#     "name": "Alice"
# }

# %%
invalid_json = '{"name": "Alice", "age": 25, "is_student": false,' # Ошибка: нет закрывающей скобки
try:
 data = json.loads(invalid_json) # Попытка загрузки некорректного JSON
 print(data) 
except json.JSONDecodeError as e:
 print(f"Ошибка декодирования JSON: {e}")
# Out:
# Ошибка декодирования JSON: Expecting property name enclosed in double quotes: line 1 column 50 (char 49)

# %%
from datetime import datetime
now = datetime.now() # Получаем текущую дату и время
print(type(now)) # Объект datetime
print(now)
# Out:
# <class 'datetime.datetime'>
# 2026-01-15 10:18:41.967610

# %%
now = datetime.now()
print("Год:", now.year)
print("Месяц:", now.month)
print("День:", now.day)
print("Часы:", now.hour)
print("Минуты:", now.minute)
print("Секунды:", now.second)
# Out:
# Год: 2026
# Месяц: 1
# День: 15
# Часы: 10
# Минуты: 21
# Секунды: 16

# %%
now = datetime.now()
# Преобразование в строку
print(str(now))
# Преобразование в строку указанного формата
formatted_date = now.strftime("%d.%m.%Y %H:%M:%S")
print(type(formatted_date))
print(formatted_date)
# Out:
# 2026-01-15 10:23:04.528972
# <class 'str'>
# 15.01.2026 10:23:04

# %%
now = datetime.now()
print(now.strftime("%Y-%m-%d")) # 2025-02-28 (ISO формат)
print(now.strftime("%d/%m/%Y")) # 28/02/2025 (европейский формат)
print(now.strftime("%I:%M %p")) # 02:30 PM (12-часовой формат)
print(now.strftime("%A, %B %d, %Y")) # Friday, February 28, 2025
# Out:
# 2026-01-15
# 15/01/2026
# 10:28 AM
# Thursday, January 15, 2026

# %%
date_string = "28|02|2025 14-30-15" # Дата в виде строки
date_obj = datetime.strptime(date_string, "%d|%m|%Y %H-%M-%S") # Указываем форматы и те же разделители
print(type(date_obj))
print(date_obj)
# Out:
# <class 'datetime.datetime'>
# 2025-02-28 14:30:15

# %%
now = datetime.now()
deadline = datetime.strptime("01.12.2025", "%d.%m.%Y")
if now > deadline:
 print("Срок истёк!")
else:
 print("До дедлайна ещё есть время.")
# Out:
# Срок истёк!

# %%
from datetime import datetime
date1 = datetime(2025, 2, 28)
date2 = datetime(2025, 3, 5)
difference = date2 - date1 # Разница между датами
print(type(difference))
print(difference)
print(difference.days)
# Out:
# <class 'datetime.timedelta'>
# 5 days, 0:00:00
# 5

# %%
from datetime import datetime
dt1 = datetime(2025, 2, 28, 14, 30)
dt2 = datetime(2025, 3, 2, 10, 0)
difference = dt2 - dt1
print(difference)
print(difference.total_seconds())
# Out:
# 1 day, 19:30:00
# 156600.0

# %%
from datetime import datetime, timedelta
# Дата начала задачи
start_date = datetime(2025, 2, 28)
# Дедлайн через 2 недели
deadline = start_date + timedelta(weeks=2)
print("Дедлайн:", deadline.strftime("%d.%m.%Y"))
# Проверка, прошёл ли дедлайн
today = datetime(2025, 3, 15) # Текущая дата
if deadline > today:
 print("Дедлайн пропущен!")
else:
 print("Ещё есть время для выполнения задачи.")
# Out:
# Дедлайн: 14.03.2025
# Ещё есть время для выполнения задачи.

# %%
from datetime import datetime, timedelta
# Дата начала задачи
start_date = datetime(2025, 2, 28)
# Дедлайн через 2 недели
deadline = start_date + timedelta(weeks=4) # чтоб прибавить 3 месяца надо прибавить 90 дней. в timedelta нет месяцев и годов
print(deadline.strftime("%d.%m.%Y"))
print(start_date.strftime("%d.%m.%Y"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       3 start_date = datetime(2025, 2, 28)
#       4 # Дедлайн через 2 недели
# ----> 5 deadline = start_date + 2
#       6 print(deadline.strftime("%d.%m.%Y"))
#       7 print(start_date.strftime("%d.%m.%Y"))
#
# TypeError: unsupported operand type(s) for +: 'datetime.datetime' and 'int'

# %%
# ?timedelta
# Out:
# Init signature: timedelta(self, /, *args, **kwargs)
# Docstring:
# Difference between two datetime values.
#
# timedelta(days=0, seconds=0, microseconds=0, milliseconds=0, minutes=0, hours=0, weeks=0)
#
# All arguments are optional and default to 0.
# Arguments may be integers or floats, and may be positive or negative.
# File:           c:\users\vitaliy\appdata\local\programs\python\python313\lib\datetime.py
# Type:           type
# Subclasses:
