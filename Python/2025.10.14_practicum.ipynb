# %%
# Округление вверх и вниз
# Напишите программу, которая:
# ● принимает число с плавающей запятой
# ● выводит результат округления вверх и вниз
# Пример вывода:
# Введите число: 4.3
# Округление вверх: 5
# Округление вниз: 4
import math 
x = float(input("Введите число: "))
print("Округление вверх:", math.floor(x))
print("Округление вниз:", math.ceil(x))
# Out:
# Введите число:  3.5
# Округление вверх: 3
# Округление вниз: 4

# %%
# Сумма чисел
# Напишите программу, которая принимает число от пользователя и выводит сумму с чисел от 1 до самого
# числа.
# Пример вывода:
# Введите число: 5
# Сумма чисел от 1 до 5  15

x = int(input("Введите число: "))
y = 0
result = 0
while y < x:
      y += 1
      result += y
print ("Сумма чисел от 1 до", x, "=", result)
# Out:
# Введите число:  7
# Сумма чисел от 1 до 7 = 28

# %%
# Счётчик факториала
# Напишите программу, которая рассчитывает факториал заданного числа
# (произведение всех целых чисел от 1 до самого числа) двумя способами.
# Выведите оба результата и сравните равны ли они.
# Пример вывода:
# Введите число: 5
# Факториал числа 5 первым способом: 120
# Факториал числа 5 вторым способом: 120
# Результаты равны? True

import math
x = int(input("Введите число: "))
y = 0
result = 1
while y < x:     
      y += 1
      result *= y 
      
print ("Факториал числа", x, "первым способом:", result)

result2 = math.factorial(x)
print ("Факториал числа", x, "вторым способом:", result2)
# Out:
# Введите число:  6
# Факториал числа 6 первым способом: 720
# Факториал числа 6 вторым способом: 720

# %%
# Симулятор кассы
# Напишите программу, которая принимает от пользователя цены товаров. Пользователь вводит цены по одному
# (ввод завершается при вводе нуля).
# Программа должна:
# ● Рассчитать и вывести общую сумму покупки, округленную до целого числа.
# ● Определить, какую сумму покупатель должен заплатить, если у него есть только купюры номиналом
# 100 евро.
# ● Рассчитать и вывести сдачу, которую нужно дать покупателю.

total = 0
k = 100
while True:
    x = float(input("Введите цену товара (или 0 для завершения): "))
    if x == 0:
        break
    total += x
print("Общая сумма покупки:", int(total), "евро")
kp = math.ceil((total) / k)
print("Клиенту необходимо отдать", kp, "купюры")
print("Ваша сдача:", kp * k - int(total), "евро")
# Out:
# Введите цену товара (или 0 для завершения):  52.66
# Введите цену товара (или 0 для завершения):  47.02
# Введите цену товара (или 0 для завершения):  2
# Введите цену товара (или 0 для завершения):  0
# Общая сумма покупки: 101 евро
# Клиенту необходимо отдать 2 купюры
# Ваша сдача: 99 евро

# %%
# Учет доходов и расходов
# Напишите программу, которая принимает на вход положительные и отрицательные значения и
# останавливается получив ноль. Программа должна рассчитать сумму доходов (положительные) и расходов
# (отрицательные), а также итоговый баланс.
# Пример вывода:
# Введите доход, расход или '0' для получения итога: 15000
# Введите доход, расход или '0' для получения итога: 5000
# Введите доход, расход или '0' для получения итога: 3000
# Введите доход, расход или '0' для получения итога: 0
# Доходы: 15000
# Расходы: 8000
# Итоговый баланс: 7000
ras = 0
doh = 0
bal = 0
while True:
    x = int(input("Введите доход, расход или '0' для получения итога: "))
    if x == 0:
        break
    elif x > 0:
        doh += x
    else:
        ras += x
bal = doh + ras
print("Доходы:" , doh)
print("Расходы:", abs(ras))
print("Итоговый баланс:", bal)
# Out:
# Введите доход, расход или '0' для получения итога:  15000
# Введите доход, расход или '0' для получения итога:  -5000
# Введите доход, расход или '0' для получения итога:  -3000
# Введите доход, расход или '0' для получения итога:  0
# Доходы: 15000
# Расходы: 8000
# Итоговый баланс: 7000

# %%
# 6 
# Последовательности Фибоначчи
# Напишите программу, которая выводит первые n чисел последовательности Фибоначчи. Число n вводится
# пользователем.
# Пример вывода:
# Введите количество чисел: 7
# 0 1 1 2 3 5 8
a = 0
b = 1
n = 0 
x = int(input("Введите число n: "))
while n < x:
    print (a, end=" ")
    fib = a + b
    n += 1
    a = b
    b = fib

# a, b = b, a + b
# n += 1
# Out:
# Введите число n:  7
# 0 1 1 2 3 5 8

# %%
# 7
# Число Армстронга
# Напишите программу, которая запрашивает у пользователя целое число и проверяет, является ли оно числом
# Армстронга. Число Армстронга — это число, которое равно сумме своих цифр, которые были возведены в
# степень, равную количеству цифр в числе.
# Например 153  1^3  5^3  3^3  1  125  27
# Пример вывода:
# Введите число: 153
# Число 153 является числом Армстронга.
# Введите число: 123
# Число 123 не является числом Армстронга.
sumx = 0
s = 0
x = int(input("Введите число: "))
x1 = x
while x1 > 0:
    x1 = x1 // 10 
    s += 1
x1 = x
while x1 > 0:
    num = x1 % 10
    sumx += num ** s
    x1 = x1 // 10 # запони забрать цифру легко x //= 10
print(s, sumx)
print("Число " + str(x) + " является числом Армстронга." if x == sumx else "Число " + str(x) + " не является числом Армстронга.")
# Out:
# Введите число:  254
# 3 197
# Число 254 не является числом Армстронга.

# %%
# 8
# Угадай за 5 попыток
# Напишите программу, которая генерирует случайное число от 1 до 10 и просит пользователя угадать его за 5
# попыток. Если пользователь не угадывает за 5 попыток, программа выводит загаданное число.
# Пример вывода:
# Попробуйте угадать число от 1 до 10 10
# Неверно! У вас осталось 4 попытки.
# Попробуйте угадать число от 1 до 50 3
# Неверно! У вас осталось 3 попытки.
# Попробуйте угадать число от 1 до 50 7
# Поздравляем! Вы угадали число.

import random
x = random.randint(1, 10)
p = 0
y = 0
while p < 5:
    y = int(input("Угадайте число от 1 до 10." ))
    p += 1
    if y == x:
        print("Поздравляем! Вы угадали число")
        break 
    else:
        print("Неверно! У вас осталось",  (5 - p), "попыток.")
         
else:
    print("К сожалению, попытки закончились. Загаданное число было:", x, ".")
# Out:
# Угадайте число от 1 до 10. 5
# Неверно! У вас осталось 4 попыток.
# Угадайте число от 1 до 10. 2
# Неверно! У вас осталось 3 попыток.
# Угадайте число от 1 до 10. 6
# Поздравляем! Вы угадали число:

# %%
# 9
# Определение простого числа
# Напишите программу, которая запрашивать число у пользователя и определяет, является ли заданное число
# простым.
# Число является простым, если оно:
# ● Больше 1.
# ● Имеет только два делителя: единицу и само себя.
# Пример вывода:
# Введите число: 29
# Число 29 является простым.
# Введите число: 15
# Число 15 не является простым.

d = 2 
x = int(input("Введите чило: "))
if x <= 1:
    print("Число " + str(x) + " не является простым")
else:
    while x > d:
        if x % d == 0:
            print("Число " + str(x) + " не является простым")
            break
        d += 1
    else:
        print("Число " + str(x) + " является простым")
# Out:
# Введите чило:  11
# Число 11 является простым

# %%
# 10
# Упорядоченность цифр
# Напишите программу, которая получает натуральное число и определяет, являются ли его цифры
# упорядоченными по возрастанию.
# Пример вывода:
# Введите число: 1347
# Цифры упорядочены по возрастанию.
# Введите число: 1523
# Цифры не упорядочены по возрастанию.

num1 = 10
x = int(input("Введите чило: "))
while x > 0:
    num = x % 10
    if num >= num1:
        print("Цифры не упорядочены по возрастанию.")
        break
    num1 = num
    x = x // 10
else:
    print("Цифры упорядочены по возрастанию.")
# Out:
# Введите чило:  6532
# Цифры не упорядочены по возрастанию.
