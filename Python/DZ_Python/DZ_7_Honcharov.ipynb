# %%
# Сумма цифр числа
# Напишите программу, которая вычисляет сумму цифр введённого числа.
# Подсказка: последнюю цифру числа можно найти с помощью остатка от деления на 10 (num % 10), 
# а удалить ее из числа можно с помощью деления на 10 нацело (num // 10).
# ------------------------------------------------------------------
# Пример вывода:
# Введите число: 12345
# Сумма цифр: 15
x = int(input("Введите целое число: "))
res = 0 
while x > 0:
     num = x % 10
     res += int(num)
     x = x // 10
print(res)
# Out:
# Введите целое число:  00011113333666
# 34

# %%
# Палиндром
# Напишите программу, которая запрашивает у пользователя целое число и определяет, является ли оно палиндромом. 
# Число является палиндромом, если оно читается одинаково слева направо и справа налево.
# ------------------------------------------------------------------
# Пример вывода:
# Введите число: 12321
# Число 12321 является палиндромом.
# Введите число: 1234
# Число 1234 не является палиндромом.
x = int(input("Введите целое число: "))
one = x
last = 0
while x > 0:
    num = x % 10
    last = last * 10 + num
    x = x // 10
if one == last:
    print("Число", one, "является палиндромом")
else:
    print("Число", one, " не является палиндромом")
# Out:
# Введите целое число:  12345654321
# Число 12345654321 является палиндромом

# %%
# Проверь интуицию
# Напишите программу, которая генерирует случайное число от 1 до 100 включительно и дает пользователю 10 попыток, чтобы угадать это число. 
# Программа должна подсказывать, больше или меньше загаданное число. После завершения игры программа оценивает, насколько хорошая интуиция у игрока.
# ------------------------------------------------------------------
# Пример вывода:
# Угадайте число от 1 до 100. У вас 10 попыток.
# Ваше предположение: 50
# Загаданное число меньше вашего
# Ваше предположение: 25
# Загаданное число больше вашего
# Ваше предположение: 30
# Поздравляем! Вы угадали число: 30.
# ------------------------------------------------------------------
# Вы угадали число за 3 попытки. Отличный результат!
# ------------------------------------------------------------------
# Угадайте число от 1 до 100. У вас 10 попыток.
# Ваше предположение: 2
# Поздравляем! Вы угадали число: 2 за 1 попыток. Отличный результат!
# Отличная интуиция! Вы угадали с первой попытки!

import random
x = random.randint(1, 100)
p = 0
y = 0
while p < 10:
    y = int(input("Угадайте число от 1 до 100. Попытка " + str(p + 1) + " из 10. \n\tВаше число: " ))
    p += 1
    if y == x:
        print("Поздравляем! Вы угадали число:", x, "за", p, "попыток.")
        break 
    elif y > x:
        print("Загаданное число меньше вашего\n -------------------------------------")
    else:
        print("Загаданное число больше вашего\n -------------------------------------")
        
if p < 10:
    if p == 1:
        u = "Отличная интуиция! Вы угадали с первой попытки!"
    elif p <= 3:
        u = "Отличный результат!"
    elif p <= 6:
        u = "Хороший результат."
    else:
        u = "Можно и лучше."
    print("Вы угадали число за", p, "попытк(и).", u)
    
else:
    print("К сожалению, попытки закончились. Загаданное число было:", x, ".")
# Out:
# Угадайте число от 1 до 100. Попытка 1 из 10.
# 	Ваше число:  50
# Загаданное число больше вашего
#  -------------------------------------
# Угадайте число от 1 до 100. Попытка 2 из 10.
# 	Ваше число:  60
# Загаданное число больше вашего
#  -------------------------------------
# Угадайте число от 1 до 100. Попытка 3 из 10.
# 	Ваше число:  70
# Загаданное число больше вашего
#  -------------------------------------
# Угадайте число от 1 до 100. Попытка 4 из 10.
# 	Ваше число:  80
# Загаданное число больше вашего
#  -------------------------------------
# Угадайте число от 1 до 100. Попытка 5 из 10.
# 	Ваше число:  90
# Загаданное число меньше вашего
#  -------------------------------------
# Угадайте число от 1 до 100. Попытка 6 из 10.
# 	Ваше число:  85
# Загаданное число меньше вашего
#  -------------------------------------
# Угадайте число от 1 до 100. Попытка 7 из 10.
# 	Ваше число:  82
# Загаданное число больше вашего
#  -------------------------------------
# ...
