# %%
# 1. Создание списка с пользовательскими данными
# Напишите программу, которая принимает список целых чисел от пользователя и добавляет каждое число в динамический массив. 
# Программа должна принимать новое число от пользователя и добавлять его в динамический массив до тех пор, пока пользователь не введет команду "Выход". 
# Выведите итоговый динамический массив на экран с помощью команды print.
# Пример вывода:
# Введите число или 'выход':: 1
# Введите число или 'выход':: 2
# Введите число или 'выход':: выход
# Итоговый динамический массив: [1, 2]
my_list = []
while True:
    x = input("Введите целое число или 'выход': ")
    if x.lower() == "выход":
        break
    else:
        y = int(x)
        my_list += [y]

print(my_list)
# Out:
# Введите целое число или 'выход':  1
# Введите целое число или 'выход':  2
# Введите целое число или 'выход':  3
# Введите целое число или 'выход':  6
# Введите целое число или 'выход':  222
# Введите целое число или 'выход':  333
# Введите целое число или 'выход':  44
# Введите целое число или 'выход':  выход
# [1, 2, 3, 6, 222, 333, 44]

# %%
# 2. Квадрат нечетных чисел
# Напишите программу, которая изменяет изначальный список и возводит в квадрат только нечётные числа.
# numbers = [4, 9, 1, 7, 2, 5, 0, 3, 7, 1, 3]
# Пример вывода:
# Изначальный список: [4, 9, 1, 7, 2, 5, 0, 3, 7, 1, 3]
# Измененный список:  [4, 81, 1, 49, 2, 25, 0, 9, 49, 1, 9]

numbers = [4, 9, 1, 7, 2, 5, 0, 3, 7, 1, 3]
numbers_new = []
i = 0 
x = ""
while i < len(numbers):
    if numbers[i] % 2 != 0:
        x = numbers[i]**2
        i += 1
        numbers_new += [x]
    else:
        x = numbers[i]
        i += 1
        numbers_new += [x] 
 
print("Изначальный список:", numbers, "\n" + "Измененный список: ",  numbers_new)
# Out:
# Изначальный список: [4, 9, 1, 7, 2, 5, 0, 3, 7, 1, 3]
# Измененный список:  [4, 81, 1, 49, 2, 25, 0, 9, 49, 1, 9]
