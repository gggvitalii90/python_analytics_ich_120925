# %%
# Задание 1
# Сложение чисел
# Напишите программу, которая принимает строку с числами через пробел и выводит сумму всех чисел.
# Пример вывода:
# Введите список чисел через пробел: 1 2 3 4 5
# Сумма чисел: 15
x = input("Введите список чисел через пробел: ")
result = 0
for i in x.split():
    if i.isdigit():
        result += int(i)
        i += i
print(result)
# Out:
# Введите список чисел через пробел:  1 2 33 44 5
# 85

# %%
# Задание 2
# Обратный список
# Напишите программу, которая принимает строку с числами через пробел и выводит его в обратном порядке.
# Обратите внимание, что в списке должны быть именно числа, а не строки.
# Пример вывода:
# Введите список чисел через пробел: 1 2 3 4 5
# Обратный список: 5, 4, 3, 2, 1
x = input("Введите список чисел через пробел: ")
result = []
list_x = x.split()[::-1]
for i in list_x:
    result += [int(i)]
result
# Out:
# Введите список чисел через пробел:  1 2 3 4 5
# [5, 4, 3, 2, 1]

# %%
x = input("Введите список чисел через пробел: ")
list_x = x.split()[::-1]
for i in range(len(list_x)):
    list_x[i] = int(list_x[i])
list_x
# Out:
# Введите список чисел через пробел:  1 2 3 4 5
# [5, 4, 3, 2, 1]

# %%
# Задание 3
# Сумма чётных и нечётных чисел
# Напишите программу, которая подсчитывает сумму чётных и нечётных чисел в списке по отдельности.
# numbers = 1, 8, 2, 0, 3, 9, 1, 10, 7, 4
# Пример вывода:
# Изначальный список: 1, 8, 2, 0, 3, 9, 1, 10, 7, 4
# Сумма чётных: 16
# Сумма нечётных: 7

numbers = [-1, 8, 2, 0, -3, -9, -1, 10, 7, -4]
ch = 0
not_ch = 0
for i in numbers:
    if i % 2 == 0:
        ch += i
    else:
        not_ch += i
print(ch)
print(not_ch)
# Out:
# 16
# -7

# %%
# Задание 4
# Максимальное число
# Напишите программу, которая выводит наибольшее число в списке, не используя встроенную функцию max(),
# а также его индекс в списке.
# numbers = [3, 12, 8, 22, 9, 25, 6, 23, 8, 7]
# Пример вывода:
# Список чисел: [3, 12, 8, 22, 9, 25, 6, 23, 8, 7]
# Наибольшее число: 25
# Индекс числа: 5
numbers = [3, 12, 8, 22, 9, 25, 6, 23, 8, 7]
n_max = numbers[0]
in_max = 0
for i in range(len(numbers)):
    if numbers[i] > n_max:
        n_max = numbers[i]
        in_max = i
        
n_max, in_max
# Out:
# (25, 5)

# %%
# Задание 5
# Перестановка соседних элементов
# Напишите программу, которая меняет местами соседние элементы списка. Пример списка: umbers = 1, 2, 3, 4,
# 5
# Пример вывода:
# Изначальный список: [1, 2, 3, 4, 5]
# Список после перестановки: [2, 1, 4, 3, 5]
numbers = [1, 2, 3, 4, 5]
new_numbers = []
for i in range(0, len(numbers)-1, 2):
    numbers[i], numbers[i+1] = numbers[i+1], numbers[i]
numbers
# Out:
# [2, 1, 4, 3, 5]

# %%
# Задание 6
# Числа и слова
# Напишите программу, которая обрабатывает строку, содержащую слова и целые числа, разделённые
# пробелами. Программа должна преобразовать строку в список, где числа преобразуются в тип int, а
# остальные элементы остаются строками и начинаются с заглавной буквы.
# text = "apple 42 banana 3 100 orange"
# Пример вывода:
# Изначальная строка: apple 42 banana 3 100 orange
# Результат: ['Apple', 42, 'Banana', 3, 100, 'Orange']

x = input("Введите строку: ")
list_x = x.split()
new_x = []
for i in list_x:
    if i.isdigit():
        new_x += [int(i)]
    else:
       new_x += [i.title()] 

print(new_x)
# Out:
# Введите строку:  apple 42 banana 3 100 orange
# ['Apple', 42, 'Banana', 3, 100, 'Orange']

# %%
text = "apple 42 banana 3 100 orange"
l = text.split()

for i in range(len(l)):
    if l[i].isdigit():
        l[i] = int(l[i])
    else:
        l[i] = l[i].capitalize()

l
# Out:
# ['Apple', 42, 'Banana', 3, 100, 'Orange']

# %%
# Задание 7
# Проверка формата email
# Напишите программу, которая проверяет, начинается ли строка с буквы, содержит ли в себе символ @, и
# заканчивается ли на .com или .de.
# Пример вывода:
# Введите email: user@example.com
# Корректный формат? True
x = input("Введите email: ")
if x[0].isalpha and "@" in x and (x.endswith(".com") or x.endswith(".de")):
    print(True)
else:
    print(False)
# Out:
# Введите email:  userexample.com
# False

# %%
# Задание 8
# Развернуть слова
# Напишите программу, которая разворачивает каждое слово в строке, сохраняя их порядок.
# Пример вывода:
# Введите строку: Python is fun
# Результат: nohtyP si nuf
x = "Python is fun"
list_x = x.split()
new_x = ""
for i in list_x:
    i = i[::-1]
    new_x += " " + i
print(new_x.lstrip(" "))
# Out:
# nohtyP si nuf

# %%
s = input("Введите строку: ")
word = s.split()
revered_word = []
for w in word:
   revered_word += [w[::-1]]
print(" ".join(revered_word))
# Out:
# Введите строку:  Python is fun
# nohtyP si nuf

# %%
# Задание 9
# Количество символов
# Напишите программу, которая подсчитывает количество букв, цифр и пробелов в строке. Также выведите
# количество остальных символов.
# Пример вывода:
# Введите строку: Python 3.12 is awesome!
# Буквы: 15
# Цифры: 3
# Пробелы: 3
# Остальные символы: 2
x = "Python 3.12 is awesome!"
# x = input("Введите строку: ")
b = 0
c = 0
p = 0
o = 0
for e in x:
    if e.isalpha():
       b += 1
    elif e.isdigit():
       c += 1
    elif e == " ":
       p += 1
    else:
       o += 1
        
        
print(len(x))
print(f"{b}, {c}, {p}, {o}")
# Out:
# 23
# 15, 3, 3, 2
# !

# %%
# Задание 10
# По одному пробелу
# Напишите программу, которая удаляет в строке лишние пробелы, оставляя только по одному пробелу между
# словами.
# text = " Hello, World! How are you? "
# Пример вывода:
# Строка: ' Hello, World! How are you? '
# Результат: 'Hello, World! How are you?'
# text = input("")
# # text = " Hello, World! How are you? "
# print(text.strip())

print(' '. join(input("").split()))
# Out:
#   Hello, World! How are     you?
# Hello, World! How are you?

# %%
# Задание 11
# Все позиции подстроки
# Напишите программу, которая ищет подстроку в строке и выводит все индексы начала вхождения подстроки.
# Пример вывода:
# Строка: Banana bAnana baNAna
# Подстрока: ban
# Позиция: 0
# Позиция: 7
# Позиция: 14
x = "Banana bAnana baNAna".lower()
b = "ban".lower()
i = x.find(b)

while i != -1:
    print(i)
    i = x.find(b, i+1)
# Out:
# 0
# 7
# 14

# %%
# Задание 12
# Кодирование строки
# Напишите программу, которая принимает строку и кодирует её с помощью следующего правила: каждая
# последовательность одинаковых символов заменяется на символ и количество его повторений. Например,
# строка aaaabbc превращается в a4b2c1.
# Пример вывода:
# Введите строку: aaaabbc
# Закодированная строка: a4b2c1
x = "aaaabbc"
result = ""
for e in x:
    result = e + str(x.count(e))
print(result)
# Out:
# c1
