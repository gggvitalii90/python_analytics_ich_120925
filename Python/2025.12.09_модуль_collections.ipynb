# %%
from time import time
current_time = time()
print(current_time)
# Out:
# 1765280667.66176

# %%
import time

current_time = time.time()
print(current_time)
# Out:
# 1765280669.8217409

# %%
from time import time
current_time = time()
print(current_time)
# Out:
# 1765280676.5669503

# %%
import time
start_time = time.time()
# Создание объекта range
range_million = range(1000000)
end_time = time.time()
print(f"Время создания range: {end_time - start_time:.10f} секунд")
start_time = time.time()
# Создание объекта списка
lst = [x for x in range(10000000)]
end_time = time.time()
print(f"Время создания list: {end_time - start_time:.10f} секунд")
# Out:
# Время создания range: 0.0000598431 секунд
# Время создания list: 0.6384630203 секунд

# %%
import time
print("Программа запущена")
time.sleep(2) # Задержка на 2 секунды
print("2 секунды спустя...")
# Out:
# Программа запущена
# 2 секунды спустя...

# %%
from collections import OrderedDict
ordered_dict = OrderedDict(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 from collections import OrderedDict
# ----> 2 ordered_dict = OrderedDict(1,2,3,4)
#
# TypeError: expected at most 1 arguments, got 4

# %%
# Импорт класса из модуля collections
from collections import OrderedDict
# Создание пустого OrderedDict
od = OrderedDict()
# Добавление элементов аналогично работе со словарем
od["a"] = 1
od["b"] = 2
od["c"] = 3
print(od)
# Out:
# OrderedDict({'a': 1, 'b': 2, 'c': 3})

# %%
from collections import OrderedDict
od = OrderedDict()
od["a"] = 1
od["b"] = 2
od["c"] = 3
od["d"] = 4
# Удаление последнего элемента
print(od.popitem())
print(od)
# Удаление первого элемента
print(od.popitem(last=False))
print(od)
# Out:
# ('d', 4)
# OrderedDict({'a': 1, 'b': 2, 'c': 3})
# ('a', 1)
# OrderedDict({'b': 2, 'c': 3})

# %%
from collections import OrderedDict
queue = OrderedDict()
queue["first"] = 1
queue["second"] = 2
queue["third"] = 3
# Удаляем элементы с начала очереди
while queue:
 print(queue.popitem(last=False))
# Out:
# ('first', 1)
# ('second', 2)
# ('third', 3)

# %%
from collections import OrderedDict
queue = OrderedDict()
queue["task1"] = "low priority"
queue["task2"] = "medium priority"
queue["task3"] = "low priority"
queue["task4"] = "high priority"
queue["task5"] = "medium priority"
# Собираем ключи для перемещения
keys_to_end = [key for key, value in queue.items() if "low" in value]
keys_to_start = [key for key, value in queue.items() if "high" in value]
# Перемещаем задачи с низким приоритетом в конец
for key in keys_to_end:
 queue.move_to_end(key)
# Перемещаем задачи с высоким приоритетом в начало
for key in keys_to_start:
 queue.move_to_end(key, last=False)
print(queue)
print(keys_to_end)
print(keys_to_start)
# Out:
# OrderedDict({'task4': 'high priority', 'task2': 'medium priority', 'task5': 'medium priority', 'task1': 'low priority', 'task3': 'low priority'})
# ['task1', 'task3']
# ['task4']

# %%
from collections import defaultdict
dd = defaultdict(int)
print(dd['missing']) # Добавлено значение 0
print(dd)
# Out:
# 0
# defaultdict(<class 'int'>, {'missing': 0})

# %%
from collections import defaultdict
# Словарь с числовым значением по умолчанию
dd = defaultdict(int)
# Присваивает ключу базовое значение int
print(dd['a'])
print(dd)
# Out:
# 0
# defaultdict(<class 'int'>, {'a': 0})

# %%
# Обновляет имеющийся ключ
dd['a'] += 1
print(dd['a'])
# Присваивает ключу базовое значение int и обновляет его

dd['b'] += 10
print(dd['b'])
print(dd)
# Out:
# 1
# 10
# defaultdict(<class 'int'>, {'a': 1, 'b': 10})

# %%
from collections import defaultdict
# Словарь с пустым списком по умолчанию
dd = defaultdict(list)
# Присваивает ключу базовое значение list и обновляет его

dd['a'].append(1)
# Обновляет список по имеющемуся ключу
dd['a'].append(2)
# Присваивает ключу базовое значение list

dd['b'].append(10)
print(dd)
# Out:
# defaultdict(<class 'list'>, {'a': [1, 2], 'b': [10]})

# %%
from collections import defaultdict
# Пользовательская функция для значения по умолчанию
def default_value():
 return "default"
dd = defaultdict(default_value)
print(dd['missing_key'])
print(dd)
# Out:
# default
# defaultdict(<function default_value at 0x0000015AA107CFE0>, {'missing_key': 'default'})

# %%
my_dict = {}
if 'a' not in my_dict:
    my_dict['a'] = []
    my_dict['a'].append(1)
my_dict
# Out:
# {'a': [1]}

# %%
from collections import defaultdict
dd = defaultdict(list)
dd['a'].append(1)
dd
# Out:
# defaultdict(list, {'a': [1]})

# %%
from collections import defaultdict
data = [("class1", "Alice"), ("class2", "Bob"), ("class1", "Charlie")]
grouped = defaultdict(list)
for group, name in data:
     grouped[group].append(name)
print(grouped["class1"])
# Out:
# ['Alice', 'Charlie']

# %%
from collections import Counter
text = "hello world"
counter = Counter(text)
print(counter)
# Out:
# Counter({'l': 3, 'o': 2, 'h': 1, 'e': 1, ' ': 1, 'w': 1, 'r': 1, 'd': 1})

# %%
from collections import Counter
words = ["apple", "banana", "apple", "cherry", "banana", "apple"]
counter = Counter(words)
print(counter)
# Out:
# Counter({'apple': 3, 'banana': 2, 'cherry': 1})

# %%
from collections import Counter
data = {"apple": 3, "banana": 2, "cherry": 1}
counter = Counter(list(data))
print(counter)
# Out:
# Counter({'apple': 1, 'banana': 1, 'cherry': 1})

# %%
counter = Counter("bananacccccccccc")
print(counter.most_common(3))
# Out:
# [('c', 10), ('a', 3), ('n', 2)]

# %%
counter = Counter({"a": 3, "b": 1, "c": 0})
iter_count = counter.elements()
print(list(iter_count))
# Out:
# ['a', 'a', 'a', 'b']

# %%
counter = Counter("banana")
counter.subtract("an")
print(counter)
# Out:
# Counter({'a': 2, 'b': 1, 'n': 1})

# %%
counter = Counter("banana")
counter.update("nan")
print(counter)
# Out:
# Counter({'a': 4, 'n': 4, 'b': 1})

# %%
c1 = Counter("banana")
c2 = Counter("apple")
print(c1 + c2)
# Out:
# Counter({'a': 4, 'n': 2, 'p': 2, 'b': 1, 'l': 1, 'e': 1})

# %%
c1 = Counter("banana")
c2 = Counter("an")
print(c1 - c2)
# Out:
# Counter({'a': 2, 'b': 1, 'n': 1})

# %%
c1 = Counter("banana")
c2 = Counter("an")
print(c1 & c2)
# Out:
# Counter({'a': 1, 'n': 1})

# %%
c1 = Counter("banana")
c2 = Counter("an")
print(c1 | c2)
# Out:
# Counter({'a': 3, 'n': 2, 'b': 1})
