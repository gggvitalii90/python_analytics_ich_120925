# %%
x = [1,2,3]
for num in x:
    print(num)
# Out:
# 1
# 2
# 3

# %%
x = [1,2,3,1,1]
x = list(set(x))
print(*x)
# Out:
# 1 2 3

# %%
x = [1,2,3,1,1]
y = []
for num in x:
    if num in y:
        continue
    else:
        y.append(num)
print(y)
# Out:
# [1, 2, 3]

# %%
x = (1,2,3,1,1)
y = ()
for num in x:
    if num in y:
        continue
    else:
        y = y +(num,)
print(y)
# Out:
# (1, 2, 3)

# %%
x = [1,2,3,1,1,'a','b', -1]
x = list(dict.fromkeys(x))
x
# Out:
# [1, 2, 3, 'a', 'b', -1]

# %%
x = [1,2,3,[1,1],2,2,['a','b']]
for num in x:
    print('='*30, num, sep='\n')
    for num1 in x:
        print(f"{num} - num \t {num1} - num1")
# Out:
# ...
# 1
# 1 - num 	 1 - num1
# 1 - num 	 2 - num1
# 1 - num 	 3 - num1
# 1 - num 	 [1, 1] - num1
# 1 - num 	 2 - num1
# 1 - num 	 2 - num1
# 1 - num 	 ['a', 'b'] - num1
# ...
# 2
# 2 - num 	 1 - num1
# 2 - num 	 2 - num1
# 2 - num 	 3 - num1
# 2 - num 	 [1, 1] - num1
# 2 - num 	 2 - num1
# 2 - num 	 2 - num1
# 2 - num 	 ['a', 'b'] - num1
# ...
# 3
# 3 - num 	 1 - num1
# 3 - num 	 2 - num1
# 3 - num 	 3 - num1
# 3 - num 	 [1, 1] - num1
# 3 - num 	 2 - num1
# 3 - num 	 2 - num1
# 3 - num 	 ['a', 'b'] - num1
# ...
# [1, 1]
# [1, 1] - num 	 1 - num1
# [1, 1] - num 	 2 - num1
# [1, 1] - num 	 3 - num1
# [1, 1] - num 	 [1, 1] - num1
# [1, 1] - num 	 2 - num1
# [1, 1] - num 	 2 - num1
# [1, 1] - num 	 ['a', 'b'] - num1
# ...
# 2
# 2 - num 	 1 - num1
# 2 - num 	 2 - num1
# 2 - num 	 3 - num1
# 2 - num 	 [1, 1] - num1
# 2 - num 	 2 - num1
# 2 - num 	 2 - num1
# 2 - num 	 ['a', 'b'] - num1
# ...
# 2
# 2 - num 	 1 - num1
# 2 - num 	 2 - num1
# 2 - num 	 3 - num1
# 2 - num 	 [1, 1] - num1
# 2 - num 	 2 - num1
# 2 - num 	 2 - num1
# ...

# %%
a = int(input('Введите число:'))

for i in range(1, a + 1):
    # print(i)
    for j in range(1, a + 1):
        # print(j, end='')
        print(f"{(i * j):^8}|", end='')
    print()
# Out:
# Введите число: 5
#    1    |   2    |   3    |   4    |   5    |
#    2    |   4    |   6    |   8    |   10   |
#    3    |   6    |   9    |   12   |   15   |
#    4    |   8    |   12   |   16   |   20   |
#    5    |   10   |   15   |   20   |   25   |

# %%
x = [1,2,3,[1,1],2,2,['a','b']]
i = 0
while i < len(x):
    print(i+1, '-', x[i])
    i += 1
# Out:
# 1 - 1
# 2 - 2
# 3 - 3
# 4 - [1, 1]
# 5 - 2
# 6 - 2
# 7 - ['a', 'b']

# %%
dictionary = {"Butterfly": ["Бабочка", 1,2,3], "Training": ("Обучение", 450)}

while True:
    x = input("Введите слово для перевода (или 'exit' для выхода): ")
    
    if x == 'exit':
        print("Программа завершена.")
        break
    
    if x in dictionary.keys():
        # for a in dictionary[x]:
        #     print(a)
        print("Перевод:", dictionary[x])
    elif x not in dictionary.keys():
        for s in dictionary.values():
            for key, value in dictionary.items():
                if x == s:
    # elif x in dictionary.values():
            # if value == x:
                    print("Перевод:", key)
                    break
    else:
        print("Перевод отсутствует.")
# Out:
# Введите слово для перевода (или 'exit' для выхода):  Бабочка
