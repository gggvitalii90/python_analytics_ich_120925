# %% [markdown]
# ### <b><font color='saddlebrown'>EDA датасета Google Play Store</font></b>

# %% [markdown]
# ##### <b><font color='saddlebrown'>Описание данных</font></b>

# %% [markdown]
# - <i>App</i> - название приложения в Google Play Store
# - <i>Category</i> - категория приложения
# - <i>Rating</i> - средний пользовательский рейтинг приложения по шкале от 1 до 5.
# - <i>Reviews</i> - количество пользовательских отзывов о приложении.
# - <i>Size</i> - размер приложения
# - <i>Installs</i> - количество установок приложения.
# - <i>Type</i> - тип приложения: Free (бесплатное) или Paid (платное).
# - <i>Price</i> - стоимость приложения в долларах США. Для бесплатных приложений значение равно 0.
# - <i>Content Rating</i> - возрастное ограничение контента
# - <i>Genres</i> - более детальная жанровая классификация приложения. Может содержать несколько жанров.
# - <i>Last Updated</i> - дата последнего обновления приложения в магазине Google Play.
# - <i>Current Ver</i> - текущая версия приложения.
# - <i>Android Ver</i> - минимальная версия Android, необходимая для установки приложения.

# %% [markdown]
# ##### <b><font color='saddlebrown'>Задача</font></b>
# Провести EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
google_play_store = pd.read_csv('..//data//googleplaystore.csv')
google_play_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google_play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
google_play_store.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
google_play_store[google_play_store['Reviews'].str.contains('M', na=False) == True]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
google_play_store.drop(10472, inplace = True)

# %%
google_play_store['Reviews'] = google_play_store['Reviews'].str.replace('null', '0').astype(int)

# %%
# 2

# %%
google_play_store[google_play_store['Size'].str.contains('M', na=False) == True]
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#        Rating  Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
google_play_store[google_play_store['Size'] == 'Varies with device']
# Out:
#                                                      App             Category  \
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# ...                                                  ...                  ...
# 10713  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10725                                          Posta App  MAPS_AND_NAVIGATION
# 10765                    Chat For Strangers - Video Chat               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %%
google_play_store[(~google_play_store["Size"].str.contains('M', na=False)==True) & (google_play_store["Size"] != "Varies with device")]
# Out:
#                                  App             Category  Rating  Reviews  \
# 58                 Restart Navigator    AUTO_AND_VEHICLES     4.0     1403
# 209                  Plugin:AOT v5.0             BUSINESS     3.1     4034
# 384    Hangouts Dialer - Call Phones        COMMUNICATION     4.0   122498
# 450                      Caller ID +        COMMUNICATION     4.0     9498
# 458                      GO Notifier        COMMUNICATION     4.2   124346
# ...                              ...                  ...     ...      ...
# 10763            FP Разбитый дисплей               FAMILY     4.5      922
# 10764              FP Transportation    AUTO_AND_VEHICLES     NaN        1
# 10798           Word Search Tab 1 FR               FAMILY     NaN        0
# 10832                       FR Tides              WEATHER     3.8     1195
# 10833                    Chemin (fr)  BOOKS_AND_REFERENCE     4.8       44
#
# ...

# %%
google_play_store[google_play_store['Size'].str.contains('k', na=False) == True]
# Out:
#                                  App             Category  Rating  Reviews  \
# 58                 Restart Navigator    AUTO_AND_VEHICLES     4.0     1403
# 209                  Plugin:AOT v5.0             BUSINESS     3.1     4034
# 384    Hangouts Dialer - Call Phones        COMMUNICATION     4.0   122498
# 450                      Caller ID +        COMMUNICATION     4.0     9498
# 458                      GO Notifier        COMMUNICATION     4.2   124346
# ...                              ...                  ...     ...      ...
# 10763            FP Разбитый дисплей               FAMILY     4.5      922
# 10764              FP Transportation    AUTO_AND_VEHICLES     NaN        1
# 10798           Word Search Tab 1 FR               FAMILY     NaN        0
# 10832                       FR Tides              WEATHER     3.8     1195
# 10833                    Chemin (fr)  BOOKS_AND_REFERENCE     4.8       44
#
# ...

# %%
google_play_store['Size'] = google_play_store['Size'].str.replace('Varies with device', '0k')

# %%
google_play_store['Size'].str[-1:]
# Out:
# 0        M
# 1        M
# 2        M
# 3        M
# 4        M
#         ..
# 10836    M
# 10837    M
# 10838    M
# 10839    k
# 10840    M
# Name: Size, Length: 10840, dtype: object

# %%
google_play_store['Size_Measure'] = google_play_store['Size'].str[-1:]

# %%
google_play_store
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google_play_store['Size'] = google_play_store['Size'].str[:-1]

# %%
google_play_store['Size'] = google_play_store['Size'].astype(float)

# %%
# for index, row in google_play_store.iterrows():
#     if row['Size_Measure'] == 'k':
#         row['Size'] = round(row['Size'] / 1024, 3)

# %%
for index, row in google_play_store.iterrows():
    if row['Size_Measure'] == 'k':
        google_play_store.loc[index, 'Size'] = round(row['Size'] / 1024, 3)

# %%
google_play_store['Size'].iloc[58]
# Out:
# np.float64(0.196)

# %%
means = (google_play_store['Size'].replace(0, np.nan).groupby(google_play_store['Category']).transform('mean'))

google_play_store['Size'] = google_play_store['Size'].replace(0, np.nan).fillna(means)

# %%
google_play_store.sort_values(by='Size')
# Out:
#                                   App            Category  Rating  Reviews  \
# 1532              Essential Resources  LIBRARIES_AND_DEMO     4.6      237
# 1553             Market Update Helper  LIBRARIES_AND_DEMO     4.1    20145
# 4983     My baby firework (Remove ad)              FAMILY     4.1       30
# 4977      Ad Remove Plugin for App2SD        PRODUCTIVITY     4.1       66
# 10072                ExDialer PRO Key       COMMUNICATION     4.5     5474
# ...                               ...                 ...     ...      ...
# 7404                  SimCity BuildIt              FAMILY     4.5  4218587
# 1758           Hungry Shark Evolution                GAME     4.5  6074334
# 1565   Talking Babsy Baby: Baby Games           LIFESTYLE     4.0   140995
# 2299             Navi Radiography Pro             MEDICAL     4.7       11
# 5427                  Ultimate Tennis              SPORTS     4.3   183004
#
#           Size      Installs  Type   Price Content Rating  \
# ...

# %%
google_play_store['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
google_play_store['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
google_play_store[google_play_store['Type'].isna() == True]
# Out:
#                             App Category  Rating  Reviews       Size Installs  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN        0  28.319023        0
#
#      Type Price Content Rating    Genres   Last Updated         Current Ver  \
# 9148  NaN     0   Everyone 10+  Strategy  June 28, 2018  Varies with device
#
#              Android Ver Size_Measure
# 9148  Varies with device            k

# %%
google_play_store.drop(9148, inplace = True)

# %%
google_play_store['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
google_play_store['Price'] = google_play_store['Price'].str.replace('$', '').astype(float)

# %%
google_play_store[google_play_store['Price']>=50]
# Out:
#                                     App      Category  Rating  Reviews  \
# 2253          Vargo Anesthesia Mega App       MEDICAL     4.6       92
# 2365          Vargo Anesthesia Mega App       MEDICAL     4.6       92
# 2390          Language Therapy: Aphasia       MEDICAL     NaN       10
# 4197             most expensive app (H)        FAMILY     4.3        6
# 4362                         💎 I'm rich     LIFESTYLE     3.8      718
# 4367           I'm Rich - Trump Edition     LIFESTYLE     3.6      275
# 5351                          I am rich     LIFESTYLE     3.8     3547
# 5354                     I am Rich Plus        FAMILY     4.0      856
# 5355                      I am rich VIP     LIFESTYLE     3.8      411
# 5356                  I Am Rich Premium       FINANCE     4.1     1867
# 5357                I am extremely Rich     LIFESTYLE     2.9       41
# 5358                         I am Rich!       FINANCE     3.8       93
# ...

# %%
sns.boxplot(google_play_store, x = 'Price')
plt.xlim(-1, 50)
plt.show()

# %%
google_play_store[google_play_store['Price']==0].count()
# Out:
# App               10039
# Category          10039
# Rating             8719
# Reviews           10039
# Size              10039
# Installs          10039
# Type              10039
# Price             10039
# Content Rating    10039
# Genres            10039
# Last Updated      10039
# Current Ver       10033
# Android Ver       10038
# Size_Measure      10039
# dtype: int64

# %%
google_play_store.count()
# Out:
# App               10839
# Category          10839
# Rating             9366
# Reviews           10839
# Size              10839
# Installs          10839
# Type              10839
# Price             10839
# Content Rating    10839
# Genres            10839
# Last Updated      10839
# Current Ver       10831
# Android Ver       10837
# Size_Measure      10839
# dtype: int64

# %%
google_free = google_play_store[google_play_store['Price']==0]

# %%
google_pay = google_play_store[google_play_store['Price']>0]

# %%
google_free['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
google_free[google_free['Content Rating']=='Unrated']
# Out:
#                          App Category  Rating  Reviews  Size Installs  Type  \
# 7312     Best CG Photography   FAMILY     NaN        1   2.5     500+  Free
# 8266  DC Universe Online Map    TOOLS     4.1     1186   6.4  50,000+  Free
#
#       Price Content Rating         Genres       Last Updated Current Ver  \
# 7312    0.0        Unrated  Entertainment      June 24, 2015         5.2
# 8266    0.0        Unrated          Tools  February 27, 2012         1.3
#
#        Android Ver Size_Measure
# 7312    3.0 and up            M
# 8266  2.3.3 and up            M

# %%
google_free['Content Rating'] = google_free['Content Rating'].replace('Unrated', 'Everyone')
# Out:
# C:\Users\Vitaliy\AppData\Local\Temp\ipykernel_20260\3812579089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_free['Content Rating'] = google_free['Content Rating'].replace('Unrated', 'Everyone')

# %%
google_free['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+'], dtype=object)

# %%
google_free['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %%
google_free['Genres'].isna().sum()
# Out:
# np.int64(0)

# %%
google_free[google_free['Genres'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, Size_Measure]
# Index: []

# %%
google_free.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#    Reviews  Size Installs  Type  Price Content Rating        Genres  \
# 0      159  19.0  10,000+  Free    0.0       Everyone  Art & Design
#
#       Last Updated Current Ver   Android Ver Size_Measure
# 0  January 7, 2018       1.0.0  4.0.3 and up            M

# %%
google_free.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10039 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10039 non-null  object
#  1   Category        10039 non-null  object
#  2   Rating          8719 non-null   float64
#  3   Reviews         10039 non-null  int64
#  4   Size            10039 non-null  float64
#  5   Installs        10039 non-null  object
#  6   Type            10039 non-null  object
#  7   Price           10039 non-null  float64
#  8   Content Rating  10039 non-null  object
#  9   Genres          10039 non-null  object
#  10  Last Updated    10039 non-null  object
#  11  Current Ver     10033 non-null  object
#  12  Android Ver     10038 non-null  object
#  13  Size_Measure    10039 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
pd.to_datetime(google_free['Last Updated'])
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10039, dtype: datetime64[ns]

# %%
google_free['Date_new'] = pd.to_datetime(google_free['Last Updated'])
# Out:
# C:\Users\Vitaliy\AppData\Local\Temp\ipykernel_20260\3630439087.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_free['Date_new'] = pd.to_datetime(google_free['Last Updated'])

# %%
google_free.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159  19.0      10,000+  Free    0.0       Everyone
# 1      967  14.0     500,000+  Free    0.0       Everyone
# 2    87510   8.7   5,000,000+  Free    0.0       Everyone
# 3   215644  25.0  50,000,000+  Free    0.0           Teen
# 4      967   2.8     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_free['Current Ver'].isna().sum()
# Out:
# np.int64(6)

# %%
google_free['Android Ver'].isna().sum()
# Out:
# np.int64(1)

# %%
google_free[google_free['Current Ver'].isna()]
# Out:
#                                    App             Category  Rating  Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2       55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1    20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2     4010
# 6803                         BT Master               FAMILY     NaN        0
# 7407                   Calculate My IQ               FAMILY     NaN       44
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN        8
#
#         Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.700      5,000+  Free    0.0       Everyone       Art & Design
# 1553   0.011  1,000,000+  Free    0.0       Everyone   Libraries & Demo
# 6322   8.700    500,000+  Free    0.0       Everyone              Tools
# 6803   0.217        100+  Free    0.0       Everyone          Education
# ...

# %%
google_free[google_free['Android Ver'].isna()]
# Out:
#                        App         Category  Rating  Reviews  Size Installs  \
# 4490  Pi Dark [substratum]  PERSONALIZATION     4.5      189   2.1  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4490  Free    0.0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver Size_Measure   Date_new
# 4490         NaN            M 2018-03-27

# %%
google_free[google_free['Rating'].isna()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#        Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
google_free.duplicated().sum()
# Out:
# np.int64(448)

# %%
google_free[google_free.duplicated()==True].sort_values(by = ['App'])
# Out:
#                                                     App            Category  \
# 1407                              10 Best Foods for You  HEALTH_AND_FITNESS
# 2543                         1800 Contacts - Lens Store             MEDICAL
# 1434                       21-Day Meditation Experience  HEALTH_AND_FITNESS
# 7035                             420 BZ Budeze Delivery             MEDICAL
# 1324                       8fit Workouts & Meal Planner  HEALTH_AND_FITNESS
# ...                                                 ...                 ...
# 3014  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3063  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3085  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3118                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 3202                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
#
# ...

# %%
google_free[google_free['App']== '10 Best Foods for You']
# Out:
#                         App            Category  Rating  Reviews  Size  \
# 1393  10 Best Foods for You  HEALTH_AND_FITNESS     4.0     2490   3.8
# 1407  10 Best Foods for You  HEALTH_AND_FITNESS     4.0     2490   3.8
#
#       Installs  Type  Price Content Rating            Genres  \
# 1393  500,000+  Free    0.0   Everyone 10+  Health & Fitness
# 1407  500,000+  Free    0.0   Everyone 10+  Health & Fitness
#
#            Last Updated Current Ver   Android Ver Size_Measure   Date_new
# 1393  February 17, 2017         1.9  2.3.3 and up            M 2017-02-17
# 1407  February 17, 2017         1.9  2.3.3 and up            M 2017-02-17

# %%
google_free = google_free.drop_duplicates(keep='first')

# %%
google_free.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9591 entries, 0 to 10840
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9591 non-null   object
#  1   Category        9591 non-null   object
#  2   Rating          8279 non-null   float64
#  3   Reviews         9591 non-null   int64
#  4   Size            9591 non-null   float64
#  5   Installs        9591 non-null   object
#  6   Type            9591 non-null   object
#  7   Price           9591 non-null   float64
#  8   Content Rating  9591 non-null   object
#  9   Genres          9591 non-null   object
#  10  Last Updated    9591 non-null   object
#  11  Current Ver     9585 non-null   object
#  12  Android Ver     9590 non-null   object
#  13  Size_Measure    9591 non-null   object
#  14  Date_new        9591 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(1), object(10)
# memory usage: 1.2+ MB

# %%
del google_free['Last Updated']

# %%
sns.boxplot(google_free, x = 'Rating')
plt.show()

# %%
sns.boxplot(google_free, x = 'Reviews')
plt.show()

# %%
google_free[google_free['Reviews']>40000000]
# Out:
#                                            App       Category  Rating  \
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 382   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 1670                            Clash of Clans           GAME     4.6
# 1879                            Clash of Clans           GAME     4.6
# 2544                                  Facebook         SOCIAL     4.1
# 2545                                 Instagram         SOCIAL     4.5
# 2604                                 Instagram         SOCIAL     4.5
# 3904                        WhatsApp Messenger  COMMUNICATION     4.4
# 3909                                 Instagram         SOCIAL     4.5
# 3943                                  Facebook         SOCIAL     4.1
# 3986                            Clash of Clans         FAMILY     4.6
# ...

# %%
sns.boxplot(google_free, x = 'Size')
plt.show()

# %%
google_free[google_free['Size']>60].sort_values(by = 'Size', ascending = False)
# Out:
#                                                     App      Category  Rating  \
# 1565                     Talking Babsy Baby: Baby Games     LIFESTYLE     4.0
# 1758                             Hungry Shark Evolution          GAME     4.5
# 8847                         Draft Simulator for FUT 18        SPORTS     4.6
# 1793                  Mini Golf King - Multiplayer Game          GAME     4.5
# 8409   Car Crash III Beam DH Real Damage Simulator 2018          GAME     3.6
# ...                                                 ...           ...     ...
# 3038                        GolfLogix GPS + Putt Breaks        SPORTS     4.0
# 9850                                               Oggy          GAME     4.5
# 10391                         Police VAZ LADA Simulator        FAMILY     3.6
# 4048                                            Dropbox  PRODUCTIVITY     4.4
# 9974                       REV Robotic Enhance Vehicles        FAMILY     4.4
#
# ...

# %%
google_free.to_pickle('df_cars_2.pkl')

# %%
google_free
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
