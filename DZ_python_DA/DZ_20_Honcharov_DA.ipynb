# %% [markdown]
# # <b><font color='teal'>Homework 20</font></b>

# %% [markdown]
# Объедините прогнозы, полученные с помощью моделей ARIMA, SARIMA и Prophet, чтобы повысить точность предсказаний.

# %%
# Импорт библиотек
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from prophet import Prophet
import numpy as np

# %%
# Загрузите датасет в датафрейм df_Dingling
df_Dingling = pd.read_csv('../data/PRSA_Data_Dingling_20130301-20170228.csv')

display(df_Dingling)
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO     O3  \
# 0          1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0   82.0
# 1          2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0   80.0
# 2          3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0   79.0
# 3          4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0   79.0
# 4          5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0   81.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...  ...    ...    ...
# 35059  35060  2017      2   28    19   11.0  11.0  2.0  2.0  200.0   99.0
# 35060  35061  2017      2   28    20   13.0  13.0  2.0  2.0  200.0  101.0
# 35061  35062  2017      2   28    21    9.0  14.0  2.0  2.0  200.0  102.0
# 35062  35063  2017      2   28    22   10.0  12.0  2.0  2.0  200.0   97.0
# 35063  35064  2017      2   28    23   13.0  16.0  4.0  9.0  500.0   74.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
# В df_Dingling создайте новый столбец datetime,
# в который соедините значения из столбцов year, month, day, hour
# Для этого используйте функцию pd.to_datetime
df_Dingling['datetime'] = pd.to_datetime(df_Dingling[['year', 'month', 'day', 'hour']])
display(df_Dingling)
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO     O3  \
# 0          1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0   82.0
# 1          2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0   80.0
# 2          3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0   79.0
# 3          4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0   79.0
# 4          5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0   81.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...  ...    ...    ...
# 35059  35060  2017      2   28    19   11.0  11.0  2.0  2.0  200.0   99.0
# 35060  35061  2017      2   28    20   13.0  13.0  2.0  2.0  200.0  101.0
# 35061  35062  2017      2   28    21    9.0  14.0  2.0  2.0  200.0  102.0
# 35062  35063  2017      2   28    22   10.0  12.0  2.0  2.0  200.0   97.0
# 35063  35064  2017      2   28    23   13.0  16.0  4.0  9.0  500.0   74.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station            datetime
# ...

# %%
# Созданный столбец сделайте индексом датафрейма (df.set_index())
df_Dingling.set_index('datetime', inplace=True)
display(df_Dingling)
# Out:
#                         No  year  month  day  hour  PM2.5  PM10  SO2  NO2  \
# datetime
# 2013-03-01 00:00:00      1  2013      3    1     0    4.0   4.0  3.0  NaN
# 2013-03-01 01:00:00      2  2013      3    1     1    7.0   7.0  3.0  NaN
# 2013-03-01 02:00:00      3  2013      3    1     2    5.0   5.0  3.0  2.0
# 2013-03-01 03:00:00      4  2013      3    1     3    6.0   6.0  3.0  NaN
# 2013-03-01 04:00:00      5  2013      3    1     4    5.0   5.0  3.0  NaN
# ...                    ...   ...    ...  ...   ...    ...   ...  ...  ...
# 2017-02-28 19:00:00  35060  2017      2   28    19   11.0  11.0  2.0  2.0
# 2017-02-28 20:00:00  35061  2017      2   28    20   13.0  13.0  2.0  2.0
# 2017-02-28 21:00:00  35062  2017      2   28    21    9.0  14.0  2.0  2.0
# 2017-02-28 22:00:00  35063  2017      2   28    22   10.0  12.0  2.0  2.0
# 2017-02-28 23:00:00  35064  2017      2   28    23   13.0  16.0  4.0  9.0
#
# ...

# %%
# Поле PM2.5 выделите в отдельный объект типа Series и назовите его series_pm25
series_pm25 = df_Dingling['PM2.5']
display(series_pm25)
# Out:
# datetime
# 2013-03-01 00:00:00     4.0
# 2013-03-01 01:00:00     7.0
# 2013-03-01 02:00:00     5.0
# 2013-03-01 03:00:00     6.0
# 2013-03-01 04:00:00     5.0
#                        ...
# 2017-02-28 19:00:00    11.0
# 2017-02-28 20:00:00    13.0
# 2017-02-28 21:00:00     9.0
# 2017-02-28 22:00:00    10.0
# 2017-02-28 23:00:00    13.0
# Name: PM2.5, Length: 35064, dtype: float64

# %%
# Изучите series_pm25 на наличие отсутствующих значений
series_pm25.isna().sum()
# Out:
# np.int64(779)

# %%
# Примите решение об удалении/заполнении отсутствующих значений и выполните это действие
display(df_Dingling[df_Dingling['PM2.5'].isna()])
display(df_Dingling.info())
display(df_Dingling.describe())
display(df_Dingling.duplicated().sum())
# Out:
#                         No  year  month  day  hour  PM2.5  PM10   SO2   NO2  \
# datetime
# 2013-04-01 08:00:00    753  2013      4    1     8    NaN   NaN   NaN   NaN
# 2013-04-01 09:00:00    754  2013      4    1     9    NaN   NaN   NaN   NaN
# 2013-04-01 10:00:00    755  2013      4    1    10    NaN   NaN   NaN   NaN
# 2013-04-01 11:00:00    756  2013      4    1    11    NaN   NaN   NaN   NaN
# 2013-04-01 12:00:00    757  2013      4    1    12    NaN   NaN   NaN   NaN
# ...                    ...   ...    ...  ...   ...    ...   ...   ...   ...
# 2017-02-20 15:00:00  34864  2017      2   20    15    NaN   NaN   NaN   NaN
# 2017-02-20 16:00:00  34865  2017      2   20    16    NaN   NaN   NaN   NaN
# 2017-02-20 18:00:00  34867  2017      2   20    18    NaN   NaN   NaN   NaN
# 2017-02-21 11:00:00  34884  2017      2   21    11    NaN   NaN  26.0  68.0
# 2017-02-21 13:00:00  34886  2017      2   21    13    NaN   NaN   NaN   NaN
#
# ...

# %%
# Будет два варианта с dropna и fillna. Я выберу dropna, так как пропущенных значений не так много, и удаление их не повлияет на общую картину данных.
series_pm25_drop = series_pm25.dropna().sort_index()
display(series_pm25_drop)
series_pm25_fill = series_pm25.interpolate(method='time').ffill().bfill().sort_index()
display(series_pm25_fill)
# Out:
# datetime
# 2013-03-01 00:00:00     4.0
# 2013-03-01 01:00:00     7.0
# 2013-03-01 02:00:00     5.0
# 2013-03-01 03:00:00     6.0
# 2013-03-01 04:00:00     5.0
#                        ...
# 2017-02-28 19:00:00    11.0
# 2017-02-28 20:00:00    13.0
# 2017-02-28 21:00:00     9.0
# 2017-02-28 22:00:00    10.0
# 2017-02-28 23:00:00    13.0
# Name: PM2.5, Length: 34285, dtype: float64
# datetime
# 2013-03-01 00:00:00     4.0
# 2013-03-01 01:00:00     7.0
# 2013-03-01 02:00:00     5.0
# 2013-03-01 03:00:00     6.0
# 2013-03-01 04:00:00     5.0
#                        ...
# 2017-02-28 19:00:00    11.0
# 2017-02-28 20:00:00    13.0
# 2017-02-28 21:00:00     9.0
# 2017-02-28 22:00:00    10.0
# 2017-02-28 23:00:00    13.0
# Name: PM2.5, Length: 35064, dtype: float64

# %%
# Агрегируйте данные по месяцам в переменную monthly_data
monthly_data_drop = series_pm25_drop.resample('ME').mean()
display(monthly_data_drop.head(3))
monthly_data_fill = series_pm25_fill.resample('ME').mean()
display(monthly_data_fill.head(3))
# Out:
# datetime
# 2013-03-31    95.705645
# 2013-04-30    55.206506
# 2013-05-31    71.402266
# Freq: ME, Name: PM2.5, dtype: float64
# datetime
# 2013-03-31    95.705645
# 2013-04-30    55.700000
# 2013-05-31    70.633737
# Freq: ME, Name: PM2.5, dtype: float64

# %% [markdown]
# #### <b><font color='teal'>Модель ARIMA</font></b>

# %%
# Постройте модель ARIMA (назовите model_pm25_arima)
# p - компонент авторегрессии (кол-во предыдущих значений)
# d - интегральный компонент (кол-во раз, которое необходимо продифференцировать данные)
# q - компонент скользящего среднего (сколько прошлых членов ошибки используется для прогнозирования)
model_pm25_drop_arima = ARIMA(monthly_data_drop, order=(4, 2, 0))

model_pm25_fill_arima = ARIMA(monthly_data_fill, order=(4, 2, 0))

# %%
# Натренируйте модель
# Результат запишите в переменную model_pm25_arima_fit
model_pm25_drop_arima_fit = model_pm25_drop_arima.fit()
model_pm25_fill_arima_fit = model_pm25_fill_arima.fit()

# %%
# В переменную forecast_arima_pm25 спрогнозируйте значения pm25 на ближайший год
forecast_arima_pm25_drop = model_pm25_drop_arima_fit.forecast(steps=12)
forecast_arima_pm25_fill = model_pm25_fill_arima_fit.forecast(steps=12)

# %%
# Нарисуйте график временного ряда + график прогнозов
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(monthly_data_drop, label='PM2.5 (dropna)', color='blue')
plt.plot(forecast_arima_pm25_drop, label='ARIMA Forecast (dropna)', color='orange')
plt.title('ARIMA Forecast for PM2.5 (dropna)')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(monthly_data_fill, label='PM2.5 (fillna)', color='green')
plt.plot(forecast_arima_pm25_fill, label='ARIMA Forecast (fillna)', color='red')
plt.title('ARIMA Forecast for PM2.5 (fillna)')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### <b><font color='teal'>Модель SARIMA</font></b>

# %%
# Создайте модель SARIMA с параметрами:
# p = 1
# d = 1
# q = 1
# P = 1
# D = 1 
# Q = 1
# s = 12
# Назовите переменную model_pm25_sarima
model_pm25_sarima_drop = SARIMAX(monthly_data_drop, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_pm25_sarima_fill = SARIMAX(monthly_data_fill, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))

# %%
# Натренируйте модель на данных и запишите результат в model_pm25_sarima_fit
model_pm25_sarima_fit = model_pm25_sarima_drop.fit()
model_pm25_sarima_fill_fit = model_pm25_sarima_fill.fit()
# Out:
# c:\Users\Vitaliy\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\Vitaliy\AppData\Local\Programs\Python\Python313\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
# В переменную forecast_pm25_sarima спрогнозируйте данные на 12 месяцев вперед
forecast_pm25_sarima_drop = model_pm25_sarima_fit.forecast(steps=12)
forecast_pm25_sarima_fill = model_pm25_sarima_fill_fit.forecast(steps=12)

# %%
# Постройте график данных + прогнозы
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(monthly_data_drop, label='PM2.5 (dropna)', color='blue')
plt.plot(forecast_pm25_sarima_drop, label='ARIMA Forecast (dropna)', color='orange')
plt.title('ARIMA Forecast for PM2.5 (dropna)')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(monthly_data_fill, label='PM2.5 (fillna)', color='green')
plt.plot(forecast_pm25_sarima_fill, label='ARIMA Forecast (fillna)', color='red')
plt.title('ARIMA Forecast for PM2.5 (fillna)')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### <b><font color='teal'>Модель Prophet</font></b>

# %%
# Из monthly_data создайте датафрейм df_pm25 со столбцами 'ds' и 'y'
df_pm25_drop = monthly_data_drop.reset_index().rename(columns={'datetime': 'ds', 'PM2.5': 'y'})
display(df_pm25_drop.head(3))
df_pm25_fill = monthly_data_fill.reset_index().rename(columns={'datetime': 'ds', 'PM2.5': 'y'})
display(df_pm25_fill.head(3))
# Out:
#           ds          y
# 0 2013-03-31  95.705645
# 1 2013-04-30  55.206506
# 2 2013-05-31  71.402266
#           ds          y
# 0 2013-03-31  95.705645
# 1 2013-04-30  55.700000
# 2 2013-05-31  70.633737

# %%
# Создайте экземпляр Prophet. Назовите model_prophet
model_prophet_drop = Prophet()
model_prophet_fill = Prophet()

# %%
# Обучите модель
model_prophet_drop.fit(df_pm25_drop)
model_prophet_fill.fit(df_pm25_fill)
# Out:
# 13:00:23 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:24 - cmdstanpy - INFO - Chain [1] done processing
# 13:00:24 - cmdstanpy - INFO - Chain [1] start processing
# 13:00:25 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Создайте фрейм future_pm25 данных для хранения прогнозов
# с периодом 12 и с частотой в месяц (ME)
future_pm25_drop = model_prophet_drop.make_future_dataframe(periods=12, freq='ME')
future_pm25_fill = model_prophet_fill.make_future_dataframe(periods=12, freq='ME')

# %%
# Сделайте прогнозы в переменную forecast_prophet_pm25
forecast_prophet_pm25_drop = model_prophet_drop.predict(future_pm25_drop)
forecast_prophet_pm25_fill = model_prophet_fill.predict(future_pm25_fill)

# %%
# Визуализируйте прогноз и нарисуйте графики компонентов
plt.figure(figsize=(15, 8))
plt.subplot(2, 1, 1)
model_prophet_drop.plot(forecast_prophet_pm25_drop, ax=plt.gca())
plt.title('Prophet Forecast for PM2.5 (dropna)')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.subplot(2, 1, 2)
model_prophet_fill.plot(forecast_prophet_pm25_fill, ax=plt.gca())
plt.title('Prophet Forecast for PM2.5 (fillna)')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.tight_layout()
plt.show()


model_prophet_drop.plot_components(forecast_prophet_pm25_drop)
model_prophet_fill.plot_components(forecast_prophet_pm25_fill)
plt.show()

# %% [markdown]
# #### <b><font color='teal'>Объединение прогнозов моделей</font></b>

# %%
# Подготовьте прогнозы модели Prophet к формату данных других моделей
# Создайте Series из столбца yhat (причем последних 12 значений - tail(12))
# Индексами созданного Series будет столбец ds датафрейма forecast_prophet_pm25
series_pm25_drop = pd.Series(forecast_prophet_pm25_drop['yhat'].tail(12).values, index=forecast_prophet_pm25_drop['ds'].tail(12))
display(series_pm25_drop)
series_pm25_fill = pd.Series(forecast_prophet_pm25_fill['yhat'].tail(12).values, index=forecast_prophet_pm25_fill['ds'].tail(12))
display(series_pm25_fill)
# Out:
# ds
# 2017-03-31    79.542658
# 2017-04-30    56.316770
# 2017-05-31    47.023555
# 2017-06-30    48.835064
# 2017-07-31    49.992557
# 2017-08-31    34.170836
# 2017-09-30    42.269875
# 2017-10-31    73.707739
# 2017-11-30    60.771598
# 2017-12-31    69.585933
# 2018-01-31    71.212289
# 2018-02-28    79.729011
# dtype: float64
# ds
# 2017-03-31    80.060560
# 2017-04-30    57.552469
# 2017-05-31    47.979125
# 2017-06-30    49.048215
# 2017-07-31    51.237820
# 2017-08-31    33.599562
# 2017-09-30    41.120360
# 2017-10-31    80.881045
# 2017-11-30    60.052846
# 2017-12-31    68.731733
# 2018-01-31    71.384766
# 2018-02-28    82.660964
# dtype: float64

# %%
# В переменную mean_forecast вычислите среднее арифметическое всех трех прогнозов (ARIMA, SARIMA, Prophet)
mean_forecast_drop = (forecast_arima_pm25_drop.values + forecast_pm25_sarima_drop.values + series_pm25_drop.values) / 3
mean_forecast_fill = (forecast_arima_pm25_fill.values + forecast_pm25_sarima_fill.values + series_pm25_fill.values) / 3
display(mean_forecast_drop)
display(mean_forecast_fill)
# Out:
# array([76.09797044, 61.94560113, 51.67003555, 51.05127516, 52.54594303,
#        41.94956845, 45.10133097, 63.56319655, 60.10617175, 69.08010592,
#        61.04413111, 55.97104376])
# array([76.79788222, 59.29455373, 50.43909477, 49.78914633, 49.49423373,
#        38.27716086, 40.03390086, 64.34572107, 56.56283305, 66.27567986,
#        54.77154541, 48.77652005])

# %%
# Постройте график данных + усредненный прогноз
plt.figure(figsize=(15, 8))
plt.subplot(2, 1, 1)
plt.plot(monthly_data_drop, label='PM2.5 (dropna)', color='blue')
# plt.plot(forecast_arima_pm25_drop, label='ARIMA Forecast (dropna)', color='orange')
# plt.plot(forecast_pm25_sarima_drop, label='SARIMA Forecast (dropna)', color='green')
# plt.plot(series_pm25_drop, label='Prophet Forecast (dropna)', color='red')
plt.plot(forecast_arima_pm25_drop.index, mean_forecast_drop, label='Mean Forecast (dropna)', color='purple', linestyle='--')
plt.title('Forecast Comparison for PM2.5 (dropna)')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(monthly_data_fill, label='PM2.5 (fillna)', color='blue')
# plt.plot(forecast_arima_pm25_fill, label='ARIMA Forecast (fillna)', color='orange')
# plt.plot(forecast_pm25_sarima_fill, label='SARIMA Forecast (fillna)', color='green')
# plt.plot(series_pm25_fill, label='Prophet Forecast (fillna)', color='red')
plt.plot(forecast_arima_pm25_fill.index, mean_forecast_fill, label='Mean Forecast (fillna)', color='purple', linestyle='--')
plt.title('Forecast Comparison for PM2.5 (fillna)')
plt.xlabel('Date')
plt.ylabel('PM2.5')
plt.legend()
plt.tight_layout()
plt.show()
