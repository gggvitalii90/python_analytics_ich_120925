# %% [markdown]
# # <b><font color='teal'>Homework 15</font></b>

# %%
# Импорт библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### <b><font color='teal'>Задание 1</font></b>
# Сгенерируйте 10 000 пар значений из равномерного распределения от 0 до 1. Вычислите сумму каждой пары и постройте гистограмму сумм.

# %%
# В переменные a и b запишите значения 0 и 1 соответственно

# %%
# В переменную data_uniform_1 сгенерируйте 10000 случайных чисел из равномерного распределения
# (Синтаксис в файле "Основы статистики" - п.Равномерное распределение)

# %%
# В переменную data_uniform_2 сгенерируйте 10000 случайных чисел из равномерного распределения
# (Синтаксис в файле "Основы статистики" - п.Равномерное распределение)

# %%
# В переменную data_uniform просуммируйте два сгенерированных набора данных

# %%
# Постройте гистаграмму для получившегося набора данных
# (Синтаксис в файле "Основы статистики" - п.Равномерное распределение)

# %% [markdown]
# ##### <b><font color='teal'>Задание 2</font></b>
# При определенных условиях распределение Пуассона можно использовать в качестве приближения к биномиальному распределению:
# - Число испытаний 𝑛 велико.
# - Вероятность успеха 𝑝 мала.
# - Произведение 𝑛𝑝 (среднее значение биномиального распределения) конечное и равно 𝜆.
# <br>
# <i>Пример:</i>
# Если у вас есть биномиальное распределение с 𝑛=1000 и 𝑝=0.003, вы можете аппроксимировать его, используя распределение Пуассона с 𝜆=𝑛𝑝=3.
# <br>
# <i>Задача:</i> сгенерировать случайные величины с биномиальным распределением, сгенерировать пуассоновские распределенные случайные величины с 𝜆 = 𝑛𝑝, построить графики распределений рядом друг с другом.

# %%
# В переменные n и p запишите значения 1000 и 0.003 соответственно

# %%
# Сгенерируйте 10000 случайных биномиальных значений в переменную data_binom
# (Синтаксис в файле "Основы статистики" - п.Биномиальное распределение)

# %%
# Сгенерируйте 10000 случайных пуассоновских значений в переменную data_poisson, где 𝜆 = 𝑛𝑝
# (Синтаксис в файле "Основы статистики" - п.Пуассоновское распределение)

# %%
# С использованием subplot() из библиотеки matplotlib постройте 2 гистограммы в один ряд:
# первый - для биномиального распределения
# второй - для пуассоновского распределения
# (Синтаксис в файле "Продвинутые возможности matplotlib" - п.2)
