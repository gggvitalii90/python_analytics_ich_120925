# %% [markdown]
# # <b><font color='teal'>Homework 21</font></b>

# %%
# Импорт библиотек
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %% [markdown]
# 1. Используйте набор данных California Housing, чтобы сравнить эффективность линейной регрессии и деревьев решений при прогнозировании цен на жилье.

# %% [markdown]
# <b>Описание данных: </b><br>
# Датасет California Housing содержит данные о ценах и других параметрах на жилье в Калифорнии.<br>
#
# Поля:
# - MedInc - медианный доход домохозяйства в block group
# - HouseAge - медианный возраст домов (лет) в block group
# - AveRooms - среднее число комнат на домохозяйство
# - AveBedrms - среднее число спален
# - Population - число людей в block group
# - AveOccup - среднее число людей на домохозяйство
# - Latitude - широта
# - Longitude - долгота

# %%
# В переменную df_california запишите датасет fetch_california_housing

# %%
# В переменную X запишите все данные из компонента data датасета

# %%
# В переменную y запишите цену из компонента target датасета

# %%
# В переменные X_train, X_test, y_train, y_test запишите обучающие и тестовые данные

# %%
# Инициализируйте модель линейной регрессии в переменную model_lin_regr

# %%
# Инициализируйте модель дерево решений в переменную model_tree_des

# %%
# Обучите обе модели на обучающих данных

# %%
# Сделайте прогнозы для тестового набора в переменные y_pred_lin_regr, y_pred_tree_dec

# %%
# Выведите на экран y_test, y_pred_lin_regr, y_pred_tree_dec и визуально сравните значения

# %%
# Оцените работу моделей с помощью метрик эффективности и сравните результаты

# %% [markdown]
# 2. Используйте набор данных Wine, чтобы предсказать качество вина на основе его химических свойств. Выберите две модели из пройденных и сравните их эффективность.
