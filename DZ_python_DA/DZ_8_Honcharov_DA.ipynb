# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1 barplot
#
# Импортируйте seaborn и скачате датасет fmri. Этот набор данных содержит данные функциональной магнитно-резонансного томографии (fMRI) из эксперимента, в котором испытуемые выполняли задания на восприятие языка. Отобразите первые 5 строчек датафрейма. Визуализируйте эффект типа события. Для этого постройте barplot, отображающий среднее значение signal для каждого события в момент времени timepoint=5. Не забудьте назвать график.

# %%
data = sns.load_dataset("fmri")
display(data.head())

data_tp5 = data[data["timepoint"] == 5]

plt.figure(figsize=(7, 4))
sns.barplot(data=data_tp5, x="event", y="signal")
plt.title("Средний signal по типу события (timepoint = 5)")
plt.xlabel("Тип события")
plt.ylabel("Средний signal")
plt.show()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# 2 Изучите влияние области на результаты томографии. Отобразите с помощью pointplot средний сигнал в каждый момент времени в зависимости от области снятия показателей. Не забудьте назвать график.

# %%
sns.pointplot(data=data, x="timepoint", y="signal", hue="region", errorbar=None)
plt.title("Средний signal по областям в каждый момент времени")
plt.xlabel("Время (timepoint)")
plt.ylabel("Средний signal")
plt.show()

# %% [markdown]
# 3 Интерактивная визуализация с помощью FacetGrid. Используя FacetGrid, постройте отдельные lineplot для каждого субъекта, каждый график должен показывать связь между временем и сигналом. Задача со звёздочкой: подписать каждый график.

# %%
sns.FacetGrid(data, col="subject", col_wrap=4, height=2.2, aspect=1.2).map(sns.lineplot, "timepoint", "signal", errorbar=None)
plt.show()
