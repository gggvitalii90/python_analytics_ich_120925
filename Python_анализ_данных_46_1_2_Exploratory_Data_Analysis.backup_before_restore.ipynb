# %% [markdown]
# 1. Подготовительный этап (Data Cleaning & Wrangling)
#
# Цель: привести данные в чистый и пригодный для анализа вид
#
# ✅ Что делаем:
#
# Удаляем дубликаты
#
# Обрабатываем пропущенные значения
#
# Приводим данные к нужному типу (int, float, datetime и т.д.)
#
# Создаём новые признаки (feature engineering)

# %% [markdown]
# 2. Описательная статистика (Descriptive Analysis)
#
# Цель: понять структуру и диапазон данных
#
# ✅ Что делаем:
#
# data.describe(), .info(), .value_counts()
#
# Смотрим среднее, минимум, максимум, стандартное отклонение
#
# Обнаруживаем выбросы и подозрительные значения

# %% [markdown]
# 3. Визуализация данных (Data Visualization)
#
# Цель: наглядно увидеть закономерности, выбросы и связи между признаками
#
# ✅ Что делаем:
#
# Гистограммы, боксплоты (boxplots), тепловые карты (heatmaps)
#
# Сравнение категорий (barplot), распределений (distplot)
#
# Связи между переменными (pairplot, scatterplot)

# %% [markdown]
# 4. Выводы и гипотезы (Insights & Hypothesis Generation)
#
# Цель: сформулировать идеи и гипотезы для построения моделей или принятия решений
#
# ✅ Что делаем:
#
# Ищем корреляции между переменными
#
# Отмечаем, какие признаки могут быть полезны для модели
#
# Обнаруживаем группы/кластеры, тенденции во времени

# %% [markdown]
# | **Этап EDA**                                      | **Цель**                                                | **Методы и действия**                 | **Что нам это даст**                                                                                                 |
# | ------------------------------------------------- | ------------------------------------------------------- | ------------------------------------- | -------------------------------------------------------------------------------------------------------------------- |
# | **A. Понимание структуры и характеристик данных** | Изучить форму и содержание набора данных                | **Определение размера набора**        | Помогает понять, достаточно ли данных для статистически значимого анализа или обучения модели.                       |
# |                                                   |                                                         | **Проверка типов переменных**         | Позволяет выбрать корректные методы обработки (например, числовые для корреляций, категориальные — для группировок). |
# |                                                   |                                                         | **Поиск пропусков и дубликатов**      | Помогает избежать искажений в результатах анализа и модели, улучшить качество данных.                                |
# | **B. Выявление аномалий и выбросов**              | Найти необычные значения, которые могут искажать выводы | **Визуализация (boxplot, histogram)** | Даёт быстрый способ увидеть выбросы и понять распределение значений.                                                 |
# |                                                   |                                                         | **Расчёт Z-оценок**                   | Помогает количественно определить выбросы и принять решение об их удалении.                                          |
# |                                                   |                                                         | **Анализ распределений**              | Позволяет оценить симметрию и наличие "хвостов", понять применимы ли нормальные методы.                              |
# | **C. Идентификация связей между переменными**     | Понять, как переменные связаны друг с другом            | **Корреляционный анализ**             | Помогает определить потенциально значимые переменные для предсказания.                                               |
# |                                                   |                                                         | **Диаграммы рассеяния**               | Визуальное подтверждение связи (линейной/нелинейной) между переменными.                                              |
# |                                                   |                                                         | **Тепловые карты корреляций**         | Даёт общую картину взаимосвязей, помогает выбрать переменные и избежать мультиколлинеарности.                        |
# | **D. Подготовка данных к анализу**                | Сделать данные пригодными для анализа и моделирования   | **Очистка и нормализация**            | Устраняет искажения, связанные с масштабами или шумом, повышает стабильность моделей.                                |
# |                                                   |                                                         | **Заполнение пропусков**              | Позволяет сохранить больше данных без потери целостности, особенно важно при малом датасете.                         |
# |                                                   |                                                         | **Кодирование и масштабирование**     | Делает категориальные признаки доступными для моделей, улучшает сходимость алгоритмов.                               |

# %% [markdown]
# | **Категория**                                                | **Описание**                                                                                | **Что включает**                                                                            |
# | ------------------------------------------------------------ | ------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------- |
# | **A. Инструменты чтения, обработки и преобразования данных** | Используются для загрузки, очистки и подготовки данных к анализу.                           | Python (`pandas`, `numpy`), SQL, R, Google Sheets, Excel                                    |
# | **B. Статистика и корреляционный анализ**                    | Позволяют количественно описать данные и оценить взаимосвязи между признаками.              | Среднее, медиана, стандартное отклонение, корреляция (Pearson, Spearman), ковариация        |
# | **C. Визуализация**                                          | Помогает выявить скрытые закономерности и тренды визуально, облегчает интерпретацию данных. | Гистограммы, ящики с усами (boxplot), диаграммы рассеяния, тепловые карты, линейные графики |

# %% [markdown]
# https://drive.google.com/file/d/1BUeHZbDGVQHPQCSCLafQcQCTyhqQq-h-/view

# %% [markdown]
# | **Этап**                             | **Описание**                                                                                                                       | **Применение к датасету авто**                                                                           |
# | ------------------------------------ | ---------------------------------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------- |
# | **A. Загрузка и первичная проверка** | Загрузка данных, просмотр первых строк, анализ структуры и типов, поиск пропусков и дубликатов.                                    | `df.head()`, `df.info()`, проверка на `null`, оценка формата чисел (например, `Mileage` в строке)        |
# | **B. Очистка и преобразование**      | Приведение данных к числовому виду, удаление/обработка пропусков, дубликатов, устранение ошибок (например, “null bhp” в мощности). | Парсинг `Mileage`, `Engine`, `Power` в float, замена "null", удаление мусора, преобразование единиц      |
# | **C. Одномерный анализ**             | Анализ распределений каждой переменной по отдельности: среднее, медиана, выбросы, категориальные значения.                         | Какой средний пробег? Сколько автомобилей с дизельным топливом? Какие значения `Seats` встречаются чаще? |
# | **D. Двумерный анализ**              | Изучение связи между переменными: корреляции, зависимость цены от пробега, года, мощности и других факторов.                       | Как `Kilometers_Driven` влияет на `Price`? Есть ли связь между `Engine` и `Power`?                       |
# | **E. Визуализация**                  | Построение графиков для лучшего понимания данных: boxplot, scatterplot, heatmap и т.п.                                             | Boxplot: цена по `Fuel_Type`, диаграмма рассеяния `Year` против `Price`, тепловая карта корреляций       |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd  # Работа с таблицами
from pathlib import Path  # Проверка существования файла

preferred_file = 'car_sales_data.csv'  # Целевой CSV

try:
    from google.colab import files  # Загрузка файла через Colab
    uploaded = files.upload()  # Открывает окно выбора файла
    file_name = next(iter(uploaded.keys()))  # Берем имя загруженного файла
    print(f"Загружен файл: {file_name}")
except ModuleNotFoundError:
    if Path(preferred_file).exists():  # Проверяем, есть ли нужный файл локально
        file_name = preferred_file
        print(f"Найден целевой файл: {file_name}")
    else:
        csv_files = sorted(Path('.').glob('*.csv'))  # Собираем список всех CSV
        print('Целевой файл не найден. Доступные CSV-файлы:')
        for i, f in enumerate(csv_files, start=1):  # Печатаем список файлов по порядку
            print(f"{i}. {f.name}")
        raise FileNotFoundError(f"Файл {preferred_file} не найден в текущей папке.")  # Останавливаем код с понятной ошибкой

data = pd.read_csv(file_name)  # Читаем CSV в DataFrame
print(f"Прочитан файл: {file_name}; размер: {data.shape}")  # Показываем имя и размер таблицы
# Out:
# Укажи нужный файл в переменной file_name. Доступные CSV-файлы:
# 1. AB_NYC_2019.csv
# 2. bank.csv
# 3. books_data_short.csv
# 4. car_sales_data.csv
# 5. Coffe_sales.csv
# 6. Coffee_sales.csv
# 7. country_wise_latest.csv
# 8. data.csv
# 9. data_for_cleaning.csv
# 10. Devideos.csv
# 11. df_covid_section.csv
# 12. events.csv
# 13. example.csv
# 14. Fifa.csv
# 15. finance_chart_apple.csv
# 16. fruits.csv
# 17. gps_traffic_data.csv
# 18. housing (1).csv
# 19. Housing.csv
# 20. KaggleV2-May-2016.csv
# 21. lyft_cab_rides.csv
# 22. movies.csv
# 23. movies_1.csv
# 24. movies_2.csv
# 25. ncr_ride_bookings.csv
# 26. netflix_titles.csv
# 27. ratings (1).csv
# 28. ratings.csv
# 29. ratings_mean.csv
# 30. Salary_Data.csv
# 31. sales_data (1).csv
# 32. sales_data.csv
# 33. sales_dataset.csv
# 34. sample_eda_data.csv
# 35. Sleep_health_and_lifestyle_dataset.csv
# 36. spotify_songs.csv
# 37. Teen_Mental_Health_Dataset.csv
# 38. titanic.csv
# 39. uber_cab_rides.csv
# 40. used_cars_data.csv
# ...

# %%
display(data.head())     # Первые 5 строк
display(data.tail())     # Последние 5 строк
# Out:
#   Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0         Ford      Fiesta          1.0    Petrol                 2002
# 1      Porsche  718 Cayman          4.0    Petrol                 2016
# 2         Ford      Mondeo          1.6    Diesel                 2014
# 3       Toyota        RAV4          1.8    Hybrid                 1988
# 4           VW        Polo          1.0    Petrol                 2006
#
#    Mileage  Price
# 0   127300   3074
# 1    57850  49704
# 2    39190  24072
# 3   210814   1705
# 4   127869   4101
#   Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0         Ford      Fiesta          1.0    Petrol                 2002
# 1      Porsche  718 Cayman          4.0    Petrol                 2016
# 2         Ford      Mondeo          1.6    Diesel                 2014
# 3       Toyota        RAV4          1.8    Hybrid                 1988
# ...

# %%
# # Все вместе

# КАК получить общую информацию
# КАК посмотреть пропуски
# КАК посмотреть уникальные значения
# КАК найти дубликаты


# — В каких колонках наибольшее количество пропусков?
# — Что с ними делать: удалять, заполнять или оставить?

# %%
data.info()  # Сводка: типы столбцов, non-null, память
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
data.describe()  # Базовая статистика по числовым колонкам
# Out:
#              S.No.         Year  Kilometers_Driven        Seats        Price
# count  7253.000000  7253.000000       7.253000e+03  7200.000000  6019.000000
# mean   3626.000000  2013.365366       5.869906e+04     5.279722     9.479468
# std    2093.905084     3.254421       8.442772e+04     0.811660    11.187917
# min       0.000000  1996.000000       1.710000e+02     0.000000     0.440000
# 25%    1813.000000  2011.000000       3.400000e+04     5.000000     3.500000
# 50%    3626.000000  2014.000000       5.341600e+04     5.000000     5.640000
# 75%    5439.000000  2016.000000       7.300000e+04     5.000000     9.950000
# max    7252.000000  2019.000000       6.500000e+06    10.000000   160.000000

# %%
data.isnull().sum()  # Количество пропусков по каждому столбцу
# Out:
# Manufacturer           0
# Model                  0
# Engine size            0
# Fuel type              0
# Year of manufacture    0
# Mileage                0
# Price                  0
# dtype: int64

# %%
data.isna().sum()  # То же, что isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Engine size            0
# Fuel type              0
# Year of manufacture    0
# Mileage                0
# Price                  0
# dtype: int64

# %%
data['Year'].nunique()  # Сколько уникальных значений в Year
# Out:
# 23

# %%
data.duplicated().sum()  # Количество строк-дубликатов
# Out:
# np.int64(12)

# %%
duplicates = data[data.duplicated(keep=False)]  # Все строки, участвующие в дубликатах
print(duplicates)
# Out:
#       Manufacturer   Model  Engine size Fuel type  Year of manufacture  \
# 2183          Ford  Mondeo          1.4    Diesel                 1987
# 5136            VW    Polo          1.2    Petrol                 2003
# 5426            VW    Polo          1.2    Petrol                 2003
# 5997        Toyota   Yaris          1.0    Petrol                 1996
# 6033            VW  Passat          1.8    Diesel                 1996
# 8881           BMW      Z4          2.4    Petrol                 1999
# 9862          Ford  Mondeo          1.4    Diesel                 1987
# 11785           VW    Polo          1.0    Petrol                 2000
# 14745          BMW      Z4          2.4    Petrol                 1999
# 18313           VW    Polo          1.2    Petrol                 2021
# 18397         Ford  Fiesta          1.2    Petrol                 2003
# 18686           VW  Passat          2.0    Diesel                 2003
# ...

# %%
data.nunique()  # Уникальные значения по каждому столбцу
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %%
data = data.drop_duplicates()  # Удаляем дубликаты и сохраняем результат
data.shape  # Проверяем новый размер таблицы
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
# Что известно про столбец New_Price? Это категориальная переменная или нет, и почему?

# %%
# Что вычисляет этот код?
missing_pct = (data.isnull().sum() / len(data)) * 100  # % пропусков по каждому столбцу
missing_pct.sort_values(ascending=False)
# Out:
# S.No.                 0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.027575
# Engine                0.634220
# Power                 0.634220
# Seats                 0.730732
# New_Price            86.129877
# Price                17.013650
# dtype: float64

# %%
missing = data.isna().sum().sort_values(ascending=False)  # Пропуски по убыванию
print(missing)
# Out:
# New_Price            6247
# Price                1234
# Seats                  53
# Engine                 46
# Power                  46
# Mileage                 2
# Fuel_Type               0
# Kilometers_Driven       0
# Year                    0
# Location                0
# Name                    0
# S.No.                   0
# Transmission            0
# Owner_Type              0
# dtype: int64

# %% [markdown]
# 🔧 Преобразование данных

# %% [markdown]
# Преобразование — это подготовка данных для моделирования: удаление лишнего, создание новых признаков, исправление ошибок, работа с типами и единицами.

# %% [markdown]
# ✅ Ключевые действия и зачем они нужны

# %% [markdown]
# | **Шаг**                           | **Код**                                                     | **Зачем это делается**                                                       |
# | --------------------------------- | ----------------------------------------------------------- | ---------------------------------------------------------------------------- |
# | Удаление неинформативных столбцов | `data.drop(['S.No.'], axis=1)`                              | Удаляем столбец, не влияющий на прогноз (идентификатор)                      |
# | Создание возраста машины          | `data['Car_Age'] = date.today().year - data['Year']`        | Возраст лучше интерпретируется моделью, чем год                              |
# | Выделение бренда и модели         | `data['Brand'] = data.Name.str.split().str[0]` и т.д.       | Название модели слишком детальное, а бренд — значимая категория              |
# | Исправление ошибок в бренде       | `replace()`                                                 | Приведение к единому виду: «Mini» ≠ «Mini Cooper»                            |
# | Удаление исходного Name           | `del data['Name']`                                          | После извлечения нужного — исходный текст не нужен                           |
# | Разделение чисел и единиц         | `str.split()` + `astype(float)`                             | Нужно отделить значения от текста (например, "18.6 kmpl")                    |
# | Преобразование km/kg в kmpl       | `data['Mileage'] = data['Mileage_num'] * (1 + 0.333 * ...)` | Унификация единиц — иначе модель будет обучаться на несопоставимых значениях |
# | Удаление временных колонок        | `del data['Mileage_num'], del data['Mileage_units']`        | Очистка после обработки                                                      |

# %%
data = data.drop(['S.No.'], axis=1)  # Удаляем служебный ID-столбец
data.info()  # Проверяем структуру после удаления
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 736.8+ KB

# %%
from datetime import date

current_year = date.today().year  # Текущий год
data['Car_Age'] = current_year - data['Year']  # Возраст авто = текущий год - год выпуска
data.head()  # Контроль результата
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age
# 0        NaN   1.75       16
# ...

# %%
data['Brand'] = data['Name'].str.split().str.get(0)  # Первый токен = бренд
data['Model'] = data['Name'].str.split().str.get(1).fillna('') + data['Name'].str.split().str.get(2).fillna('')  # Части названия = модель
data.sample(10)  # Случайная проверка
# Out:
#                                                  Name    Location  Year  \
# 4930                    Hyundai Grand i10 CRDi Sportz  Coimbatore  2017
# 3567                  Mercedes-Benz CLA 200 CDI Sport       Kochi  2019
# 5907              Renault Duster 110PS Diesel RxZ AMT  Coimbatore  2017
# 2845                           Hyundai i20 Sportz 1.2     Kolkata  2013
# 6444                                Chevrolet Beat LT        Pune  2010
# 3965                              Honda Accord 2.4 AT      Mumbai  2011
# 3105                              Honda Accord 2.4 MT   Ahmedabad  2009
# 426    Mercedes-Benz New C-Class C 200 CGI Avantgarde      Mumbai  2011
# 5607  Volkswagen Jetta 2013-2015 2.0L TDI Highline AT        Pune  2015
# 6141                             Toyota Etios Liva GD      Jaipur  2012
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 4930              60993    Diesel       Manual      First   24.0 kmpl
# ...

# %%
print(data['Brand'].unique())  # Список уникальных брендов
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#  'Lamborghini' 'Hindustan' 'OpelCorsa']

# %%
data['Brand'] = data['Brand'].replace({'ISUZU': 'Isuzu', 'Mini': 'Mini Cooper', 'Land': 'Land Rover'})  # Унифицируем названия брендов

# %%
del data['Name']  # Удаляем исходный текстовый столбец после выделения Brand/Model

# %%
data['Mileage_num'] = data['Mileage'].str.split().str.get(0)  # Число до единицы измерения
data['Mileage_units'] = data['Mileage'].str.split().str.get(1)  # Единица измерения (kmpl/km/kg)
data['Mileage_num'] = data['Mileage_num'].astype(float)  # Преобразуем к float

# %%
print(data.isnull().sum())  # Пропуски по столбцам
print(data['Mileage_units'].unique())  # Какие единицы расхода встречаются
data.info()  # Финальная проверка типов
# Out:
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# Car_Age                 0
# Brand                   0
# Model                   1
# Mileage_num             2
# Mileage_units           2
# dtype: int64
# ['km/kg' 'kmpl' nan]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           7253 non-null   object
#  1   Year               7253 non-null   int64
#  2   Kilometers_Driven  7253 non-null   int64
#  3   Fuel_Type          7253 non-null   object
#  4   Transmission       7253 non-null   object
# ...

# %%
data['Mileage'] = data['Mileage_num'] * (1 + 0.333 * (data['Mileage_units'] == 'km/kg'))  # Приводим km/kg к сопоставимому kmpl
del data['Mileage_num']  # Удаляем временный столбец
del data['Mileage_units']  # Удаляем временный столбец
data.info()  # Проверяем итоговую структуру
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           7253 non-null   object
#  1   Year               7253 non-null   int64
#  2   Kilometers_Driven  7253 non-null   int64
#  3   Fuel_Type          7253 non-null   object
#  4   Transmission       7253 non-null   object
#  5   Owner_Type         7253 non-null   object
#  6   Mileage            7251 non-null   float64
#  7   Engine             7207 non-null   object
#  8   Power              7207 non-null   object
#  9   Seats              7200 non-null   float64
#  10  New_Price          1006 non-null   object
#  11  Price              6019 non-null   float64
#  12  Car_Age            7253 non-null   int64
#  13  Brand              7253 non-null   object
#  14  Model              7252 non-null   object
# dtypes: float64(3), int64(3), object(9)
# ...

# %%
# Как проверить, что в категориальных столбцах Fuel_Type, Transmission, Owner_Type нет опечаток? Сделайте это.
# Out:
# Fuel type:
# ['Diesel', 'Hybrid', 'Petrol']

# %%
# Столбец “Seats” – количество мест в автомобиле – имеет тип float64. Корректно ли это? Нужно ли его преобразовать к целочисленному типу? Возможно ли это?
# Out:
# Колонка 'Seats' отсутствует в текущем файле — шаг пропускаем.

# %% [markdown]
# 2. Описательная статистика (Descriptive Analysis)

# %% [markdown]
# После подготовки данных (очистка, преобразование форматов и т. д.) начинается главный аналитический этап — изучение самих данных.

# %% [markdown]
# 🎯 Цели основного этапа EDA:
#
# Поиск выбросов (outliers): аномальные значения, которые могут искажать анализ и модели.
#
# Обнаружение закономерностей и трендов: какие переменные связаны, какие значения чаще встречаются и как они распределены.
#
# Получение углублённого понимания данных: для лучшего решения бизнес-задач (например, ценообразование автомобилей).
#
# Выбор стратегии обработки пропущенных значений: например, удаление строк, замена средним/медианой и др.

# %% [markdown]
# 🔢 Инструменты анализа:
#
# data.describe() — базовая описательная статистика (mean, std, min, max и пр.) для числовых столбцов.
#
# data.describe(include='all') — расширенная статистика, включая категориальные признаки (уникальные значения, частота и т. д.).

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven      Mileage        Seats        Price  \
# count  7253.000000       7.253000e+03  7251.000000  7200.000000  6019.000000
# mean   2013.365366       5.869906e+04    18.224336     5.279722     9.479468
# std       3.254421       8.442772e+04     4.779547     0.811660    11.187917
# min    1996.000000       1.710000e+02     0.000000     0.000000     0.440000
# 25%    2011.000000       3.400000e+04    15.260000     5.000000     3.500000
# 50%    2014.000000       5.341600e+04    18.190000     5.000000     5.640000
# 75%    2016.000000       7.300000e+04    21.100000     5.000000     9.950000
# max    2019.000000       6.500000e+06    44.708820    10.000000   160.000000
#
#            Car_Age
# count  7253.000000
# mean     12.634634
# std       3.254421
# min       7.000000
# 25%      10.000000
# 50%      12.000000
# 75%      15.000000
# max      30.000000

# %%
data.describe(include='all').T
# Out:
#                     count unique         top  freq          mean  \
# Location             7253     11      Mumbai   949           NaN
# Year               7253.0    NaN         NaN   NaN   2013.365366
# Kilometers_Driven  7253.0    NaN         NaN   NaN  58699.063146
# Fuel_Type            7253      5      Diesel  3852           NaN
# Transmission         7253      2      Manual  5204           NaN
# Owner_Type           7253      4       First  5952           NaN
# Mileage            7251.0    NaN         NaN   NaN     18.224336
# Engine               7207    150     1197 CC   732           NaN
# Power                7207    386      74 bhp   280           NaN
# Seats              7200.0    NaN         NaN   NaN      5.279722
# New_Price            1006    625  95.13 Lakh     6           NaN
# Price              6019.0    NaN         NaN   NaN      9.479468
# Car_Age            7253.0    NaN         NaN   NaN     12.634634
# ...

# %% [markdown]
# Какие выводы можно сделать?

# %%
# Одномерный анализ (univariate analysis) — это изучение распределения одной переменной (одного столбца) в данных.
# Цель — понять, как ведёт себя эта переменная: какие у неё значения, есть ли перекос (асимметрия),
# выбросы, редкие категории и т.п. Этот шаг не зависит от других переменных — мы смотрим на каждый столбец по отдельности.

# %% [markdown]
# | Пункт           | Описание                                                                                 |
# | --------------- | ---------------------------------------------------------------------------------------- |
# | 🎯 Цель         | Изучить поведение **каждой переменной по отдельности**                                   |
# | 🔍 Что ищем     | Асимметрия, выбросы, пики, редкие категории                                              |
# | 🛠️ Инструменты | Гистограммы, boxplot'ы, countplot'ы                                                      |
# | 🧠 Что даёт     | Помогает принять решения: что трансформировать, где убрать выбросы, какие признаки важны |

# %%
# 🔹 1. Разделение переменных

cat_cols = data.select_dtypes(include=['object']).columns.tolist()
num_cols = data.select_dtypes(include=np.number).columns.tolist()

print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)


# Категориальные переменные: тип object, например "Fuel", "Transmission", "Seller_Type".

# Числовые переменные: тип int или float, например "Price", "Kilometers_Driven".
# Out:
# Categorical Variables:
# ['Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Engine', 'Power', 'New_Price', 'Brand', 'Model']
# Numerical Variables:
# ['Year', 'Kilometers_Driven', 'Mileage', 'Seats', 'Price', 'Car_Age']

# %%
# 🔹 2. Анализ числовых переменных

for col in num_cols:
    print(col)
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()

# Строим гистограмму (hist) — показывает распределение: есть ли пики, нормальность, асимметрия.

# Строим boxplot — показывает медиану, квартиль, выбросы.

# Kilometers_Driven

# Гистограмма покажет: большинство машин проехали мало, но есть редкие случаи с 500 000 км.

# Boxplot покажет: основная масса данных сжата, есть длинные «усы» — выбросы.
# Out:
# Year
# Kilometers_Driven
# Mileage
# Seats
# Price
# Car_Age

# %%
# 🔹 3. Анализ категориальных переменных

cat_cols_clean = [col for col in cat_cols if data[col].nunique() < 30]

num_cols = 2
num_rows = (len(cat_cols_clean) + 1) // 2

fig, axes = plt.subplots(num_rows, num_cols, figsize=(18, 6 * num_rows))
axes = axes.flatten()

for i, col in enumerate(cat_cols_clean):
    sns.countplot(ax=axes[i], x=col, data=data, color='blue')
    axes[i].set_title(col)
    axes[i].tick_params(axis='x', labelrotation=90)  # поворот всех подписей

for j in range(len(cat_cols_clean), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()



# Показываем, сколько раз встречается каждая категория.

# Например:

# "Fuel" → бензин, дизель, газ

# "Seller_Type" → индивидуальный, дилер

# %%
# 🔹 4. Логарифмическое преобразование

data['Kilometers_Driven_log'] = np.log1p(data['Kilometers_Driven'])


# Если данные сильно перекошены (например, 90% значений — маленькие, а 10% — огромные), алгоритмы машинного обучения могут работать хуже.

# Логарифм:

# Сжимает большие значения

# Распределение становится более симметричным

# %%
# Можно сравнить до и после:

plt.figure(figsize=(14, 4))

plt.subplot(1, 2, 1)
data['Kilometers_Driven'].hist()
plt.title('До логарифма')

plt.subplot(1, 2, 2)
data['Kilometers_Driven_log'].hist()
plt.title('После логарифма')

plt.show()

# %% [markdown]
# 📊 Многомерный анализ (Multivariate Analysis)

# %% [markdown]
# Многомерный анализ — это изучение сразу нескольких переменных (в отличие от одномерного анализа), чтобы понять взаимосвязи между ними, в том числе:
#
# какие переменные влияют на целевую переменную (например, Price)
#
# какие переменные дублируют друг друга
#
# есть ли скрытые закономерности

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Убедимся, что числовые колонки в нужном виде
# Преобразуем 'Engine' и 'Power' из текстового формата в числа
data['Engine'] = data['Engine'].str.extract('(\d+\.?\d*)').astype(float)
data['Power'] = data['Power'].str.extract('(\d+\.?\d*)').astype(float)

# Создаём новые логарифмированные столбцы
if 'Kilometers_Driven_log' not in data.columns:
    data['Kilometers_Driven_log'] = np.log1p(data['Kilometers_Driven'])

if 'Price_log' not in data.columns:
    data['Price_log'] = np.log1p(data['Price'])

# Удалим строки с пропущенными значениями, чтобы pairplot не упал
pairplot_cols = ['Kilometers_Driven_log', 'Mileage', 'Engine', 'Power', 'Seats', 'Price_log', 'Car_Age']
data_clean = data[pairplot_cols].dropna()

# Строим pairplot
sns.pairplot(data_clean)
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Vitaliy\AppData\Local\Temp\ipykernel_40584\3119796292.py:8: SyntaxWarning: invalid escape sequence '\d'
#   data['Engine'] = data['Engine'].str.extract('(\d+\.?\d*)').astype(float)
# C:\Users\Vitaliy\AppData\Local\Temp\ipykernel_40584\3119796292.py:9: SyntaxWarning: invalid escape sequence '\d'
#   data['Power'] = data['Power'].str.extract('(\d+\.?\d*)').astype(float)

# %%
import math
#Теперь построим столбчатые диаграммы для анализа влияния категориальных переменных на цену автомобиля.

# Категориальные переменные с не слишком большим числом уникальных значений
cat_cols_small = [col for col in cat_cols if data[col].nunique() <= 20]

# Расчёт размеров сетки графиков
n = len(cat_cols_small)
cols = 2
rows = math.ceil(n / cols)

fig, axes = plt.subplots(rows, cols, figsize=(10, 5 * rows))
axes = axes.flatten()

for i, col in enumerate(cat_cols_small):
    data.groupby(col)['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axes[i])
    axes[i].set_title(f'Средняя Price_log по {col}')
    axes[i].tick_params(axis='x', labelrotation=45)

# Удалить пустые графики
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
fig, axarr = plt.subplots(1, 2)
data.groupby('Seats')['Price_log'].mean().plot.bar(ax=axarr[0])
data.groupby('Car_Age')['Price_log'].mean().plot.bar(ax=axarr[1])
plt.show()

#Какие выводы можно сделать из столбчатых диаграмм?

# %%
# 📊 Многомерный анализ?

# %%
# Многомерный анализ (multivariate analysis) — это метод анализа, при котором одновременно рассматриваются
# три и более переменных для выявления взаимосвязей, закономерностей, влияний и потенциальной избыточности (например, дублирующие признаки).

# В контексте машинного обучения или EDA (разведочного анализа данных), многомерный анализ помогает:

# понять, какие переменные наиболее важны для прогнозирования;
# выявить мультиколлинеарность (две переменные дублируют друг друга);
# улучшить интерпретируемость и упростить модель.

# %%
plt.figure()
sns.heatmap(data[['Kilometers_Driven_log', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power', 'Seats', 'Price_log',  'Price', 'Car_Age']].corr(), annot=True)
plt.show()

# .corr() — считает матрицу корреляций Пирсона между числовыми переменными:

# Значения от -1 до 1

# +1 → идеально положительная линейная зависимость

# -1 → идеально отрицательная линейная

# 0 → линейной связи нет

# sns.heatmap(..., annot=True) — визуально показывает:

# цвет: от синего (отрицательно) до красного (положительно)

# цифра внутри: точное значение корреляции

# %% [markdown]
# 📍 5. Заполнение пропущенных значений (Handling Missing Values)

# %%
# 1. Обнаружение некорректных значений

data.loc[data["Mileage"] == 0.0, 'Mileage'] = np.nan

# Заменяем подозрительные 0.0 в расходе топлива на NaN — это логично, потому что машина с расходом 0 невозможна.

# %%
data.Mileage.isnull().sum()
data['Mileage'] = data['Mileage'].fillna(value=np.mean(data['Mileage']))


median_values = data.groupby(['Model', 'Brand'])['Seats'].transform('median')
data.loc[data['Seats'].isnull(), 'Seats'] = data['Seats'].fillna(median_values)


# что тут происходит
# → Сколько % значений пропущено?
# → Это много или мало?
# Out:
# Пропусков Mileage: 0 (0.00%)
# Колонка 'Seats' отсутствует — шаг заполнения Seats пропущен.

# %% [markdown]
# Модели одной марки часто имеют одинаковое число мест.
#
# Мы группируем по Model + Brand, вычисляем медиану по группе, и подставляем её.
#
# 📌 Такой подход называется групповым заполнением по агрегату — он даёт гораздо более реалистичные результаты.

# %% [markdown]
# | Вопрос                                                              | Обсуждение                                                                       |
# | ------------------------------------------------------------------- | -------------------------------------------------------------------------------- |
# | 🔍 Где и почему могут быть пропуски?                                | Ошибки ввода, неуказанные параметры, редкие модели                               |
# | 📈 Какой метод заполнения выбрать?                                  | Среднее, медиана, мода, группировка, ML                                          |
# | 🚫 Когда лучше вообще **не заполнять**?                             | Если данных слишком мало или это важный сигнал                                   |
# | 🧪 Почему `Seats` лучше заполнять по модели, а `Mileage` — средним? | Потому что `Seats` зависит от конструкции, а `Mileage` — от условий эксплуатации |
# | ⚠️ Как влияет заполнение на последующий анализ/модель?              | Может искажать распределения, давать ложные выводы                               |

# %%
#запись датафрейма в файл
data.to_pickle("cars.pkl")

#чтение датафрейма из файла
new_df=pd.read_pickle("cars.pkl")
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         50000 non-null  object
#  1   Model                50000 non-null  object
#  2   Engine size          50000 non-null  float64
#  3   Fuel type            50000 non-null  object
#  4   Year of manufacture  50000 non-null  int64
#  5   Mileage              50000 non-null  int64
#  6   Price                50000 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.7+ MB
