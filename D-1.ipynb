# %% [markdown]
# 🔍 A. Понимание структуры и характеристик данных

# %% [markdown]
# | Метрика                     | Значение                                                                                     |
# | --------------------------- | -------------------------------------------------------------------------------------------- |
# | 📦 **Размер данных**        | 21 строка × 6 колонок                                                                        |
# | 🧬 **Типы переменных**      | Числовые (`Age`, `Salary`), категориальные (`Gender`, `Department`), временные (`StartDate`) |
# | 🧯 **Пропущенные значения** | В колонке `Age` — 2 пропущенных значения                                                     |
# | 📎 **Дубликаты**            | 1 дублированная строка                                                                       |

# %% [markdown]
# ⚠️ B. Выявление выбросов и аномалий

# %% [markdown]
# Age:
#
# Выброс: значение 150 (вне человеческого диапазона)
#
# Salary:
#
# Выброс: 1,000,000 и 300,000 — значительно выше остальных

# %% [markdown]
# 🔗 C. Корреляции между переменными
#
# Коэффициент корреляции между Age и Salary: 0.95
#
# Очень сильная положительная связь: чем выше возраст, тем выше зарплата

# %% [markdown]
# 🧹 D. Подготовка данных
#
# Пропуски в Age были заполнены средним значением;
#
# Можно продолжить:
#
# Масштабирование Salary;
#
# Кодирование Gender и Department (one-hot или label encoding);
#
# Удаление выбросов или их замена;
#
# Удаление дубликатов.

# %% [markdown]
# ✅ ЧЕК-ЛИСТ: Данные готовы к анализу/моделированию

# %% [markdown]
# 1. Пропущенные значения обработаны
#
# Нет NaN, None, null, пустых строк, если они критичны
#
# Или: выбрана стратегия — удалить / заполнить / оставить как есть
#
# 2. Типы данных корректны
#
# Числовые переменные — в int/float
#
# Категориальные — в category или object
#
# Даты — в datetime
#
# Нет «перемешанных» типов в одном столбце
#
# 3. Нет дубликатов
#
# Дубликаты строк удалены (если они не нужны)
#
# Нет дубликатов по id, если он должен быть уникален
#
# 4. Обнаружены и обработаны выбросы
#
# Выбросы проверены (например, через boxplot или z-score)
#
# Обосновано: оставить, удалить, заменить
#
# 5. Формат данных единообразный
#
# Например: даты — в одном формате
#
# Текст — без лишних пробелов, символов
#
# Категории — без дублей вроде "Yes" и "yes"
#
# 6. Категориальные признаки закодированы (если нужно)
#
# Для ML-моделей: применён One-Hot Encoding или Label Encoding
#
# 7. Числовые признаки масштабированы (если нужно)
#
# Например: StandardScaler / MinMaxScaler — для алгоритмов, чувствительных к
#
# масштабу (KNN, SVM, лин. регрессия и др.)
#
# 8. Целевой признак (target) определён и чист
#
# Нет NaN, выбросов, некорректных значений
#
# 9. Структура данных понятна
#
# Проведён EDA, визуализированы распределения и взаимосвязи
#
# Известны размеры, соотношения классов, баланс и т.п.
#
# 10. Разделение на train/test (если нужно) выполнено
#
# Данные не «перетекут» из train в test
#
# Стратифицированное разбиение — если важно сохранить пропорции

# %% [markdown]
# *************Если ты доверяешь своим данным и можешь объяснить, что в них, почему, откуда и в каком виде — значит они подготовлены.*******************
